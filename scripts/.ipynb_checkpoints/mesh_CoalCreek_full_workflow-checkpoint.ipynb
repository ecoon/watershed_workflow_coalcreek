# %% [markdown]
# # Complete Workflow: Coal Creek, CO
#
# This workflow provides a complete working example to develop an unstructured mesh for an integrated hydrologic model at the Coal Creek catchment in the Taylor River Basin in Colorado.
#
# It uses the following datasets:
#
# * `NHD Plus` for the watershed boundary and hydrography.
# * `NED` for elevation
# * `NLCD` for land cover/transpiration/rooting depths
# * `GLYHMPS` geology data for structural formations
# * `SoilGrids 2017` for depth to bedrock and soil texture information
# * `SSURGO` for soil data, where available, in the top 2m.
#
# This workflow creates the following files:
#
# * Mesh file: `CoalCreek.exo`, includes all labeled sets
# * Forcing: DayMet data -- daily raster of precip, RH, incoming radiation, etc.
#   - `CoalCreek_DayMet_1980_2020.h5`, the DayMet data on this watershed
#   - `CoalCreek_DayMet_typical_1980_2020.h5`, a "typical year" of DayMet, smoothed for spinup purposes, then looped 40 years
# * Forcing: LAI data -- every 4 days, time series by land cover type of LAI
#   - `CoalCreek_MODIS_LAI_smoothed_2002_2020.h5`, the LAI, interpolated and smoothed from the raw MODIS data
#   - `CoalCreek_MODIS_LAI_typical_1980_2020.h5`, a "typical year" of LAI, smoothed for spinup purposes then looped 40 years
# * Input files: ATS xml files
#   - `spinup-steadystate-CoalCreek.xml` the steady-state solution based on uniform application of mean rainfall rate
#   - `spinup-cyclic_steadystate-CoalCreek.xml` the cyclic steady state based on typical years
#   - `transient-CoalCreek.xml` the forward model

# %%
# Parameters cell -- this provides all parameters that can be changed via pipelining to generate a new watershed.
name = 'CoalCreek' # name the domain, used in filenames, etc
hucs = ['140200010204',] # a list of HUCs to run
simplify = 80 # length scale to target average edge

ignore_small_rivers = 2 # ignore rivers which have this or fewer reaches.  likely they are irrigation ditches
                        # or other small features which make things complicated but likely don't add much value
prune_by_area_fraction = 0.03 # ignore reaches whose accumulated catchment area is less than this fraction of the
                              # full domain's area
    
start_year = 1980  # year to start simulation

log_to_file = False  # if true, write to file instead of in the notebook output

# %%
# parameter checking
assert(simplify > 0 and simplify < 300)
assert(ignore_small_rivers == None or (ignore_small_rivers >= 0 and ignore_small_rivers <= 100))
assert(prune_by_area_fraction == None or (prune_by_area_fraction >= 0 and prune_by_area_fraction < 1))
assert(start_year >= 1980 and start_year < 2020)

# %%
# a dictionary of outputs -- will include all filenames generated
outputs = {}

# %%
# conda package imports
import os,sys
import numpy as np
import shapely
import logging
import scipy.ndimage
from matplotlib import pyplot as plt
import h5py
import pandas
pandas.options.display.max_columns = None

# Watershed Workflow
import workflow
import workflow.source_list
import workflow.ui
import workflow.colors
import workflow.condition
import workflow.mesh
import workflow.split_hucs
import workflow.soil_properties
import workflow.daymet

if log_to_file:
    outputs['logfile'] = f'{name}.log'
    # is this right?  the file handle will become stale... test once this is pipelined.
    with open(outputs['logfile'], 'w') as fid:
        workflow.ui.setup_logging(1,fid)
else:
    workflow.ui.setup_logging(1,None)

# ats_input_spec library, to be moved to amanzi_xml
import ats_input_spec
import ats_input_spec.public
import ats_input_spec.io

# amanzi_xml, included in AMANZI_SRC_DIR/tools/amanzi_xml
import amanzi_xml.utils.io as aio
import amanzi_xml.utils.search as asearch
import amanzi_xml.utils.errors as aerrors

# from $ATS_SRC_DIR/tools/utils
import smooth_met_box

# %%
# Note that, by default, we tend to work in the DayMet CRS because this allows us to avoid
# reprojecting meteorological forcing datasets.
crs = workflow.crs.daymet_crs()

# %% [markdown]
# ## Sources and setup
#
# Next we set up the source watershed and coordinate system and all data sources for our mesh.  We will use the CRS that is included in the shapefile.

# %%
logging.info("")
logging.info(f"Meshing shape: {hucs}")
logging.info("="*30)
# Out:
# 2021-07-23 10:13:48,262 - root - INFO:
# 2021-07-23 10:13:48,264 - root - INFO: Meshing shape: ['140200010204']
# 2021-07-23 10:13:48,265 - root - INFO: ==============================

# %% [markdown]
# A wide range of data sources are available; here we use the defaults except for using NHD Plus for watershed boundaries and hydrography (the default is NHD, which is lower resolution and therefore smaller download sizes).

# %%
# set up a dictionary of source objects
sources = workflow.source_list.get_default_sources()
sources['hydrography'] = workflow.source_list.hydrography_sources['NHD Plus']
sources['HUC'] = workflow.source_list.huc_sources['NHD Plus']
workflow.source_list.log_sources(sources)
# Out:
# 2021-07-23 10:13:48,272 - root - INFO: Using sources:
# 2021-07-23 10:13:48,274 - root - INFO: --------------
# 2021-07-23 10:13:48,274 - root - INFO: HUC: National Hydrography Dataset Plus High Resolution (NHDPlus HR)
# 2021-07-23 10:13:48,275 - root - INFO: hydrography: National Hydrography Dataset Plus High Resolution (NHDPlus HR)
# 2021-07-23 10:13:48,276 - root - INFO: DEM: National Elevation Dataset (NED)
# 2021-07-23 10:13:48,277 - root - INFO: soil structure: National Resources Conservation Service Soil Survey (NRCS Soils)
# 2021-07-23 10:13:48,277 - root - INFO: geologic structure: GLHYMPS version 2.0
# 2021-07-23 10:13:48,278 - root - INFO: land cover: National Land Cover Database (NLCD) Layer: NLCD_2016_Land_Cover_L48
# 2021-07-23 10:13:48,279 - root - INFO: soil thickness: None
# 2021-07-23 10:13:48,279 - root - INFO: meteorology: DayMet 1km

# %%
# load the huc
my_hucs = []
for huc in hucs:
    _, ws = workflow.get_huc(sources['HUC'], huc, crs)
    my_hucs.append(ws)
    
watershed = workflow.split_hucs.SplitHUCs(my_hucs)
# Out:
# 2021-07-23 10:13:48,286 - root - INFO:
# 2021-07-23 10:13:48,287 - root - INFO: Loading HUC 140200010204
# 2021-07-23 10:13:48,287 - root - INFO: ------------------------------
# 2021-07-23 10:13:48,288 - root - INFO:
# 2021-07-23 10:13:48,289 - root - INFO: Loading level 12 HUCs in 140200010204
# 2021-07-23 10:13:48,290 - root - INFO: ------------------------------
# 2021-07-23 10:13:48,292 - root - INFO: Using HUC file "/Users/uec/code/watershed_workflow/data-library/hydrography/NHDPlus_H_1402_GDB/NHDPlus_H_1402.gdb"
# 2021-07-23 10:13:48,382 - root - INFO: ... found 1 HUCs
# 2021-07-23 10:13:48,383 - root - INFO:   -- 140200010204
# 2021-07-23 10:13:48,395 - root - INFO: Converting to out_crs
# 2021-07-23 10:13:48,431 - root - INFO: Converting to shapely
# 2021-07-23 10:13:48,434 - root - INFO: ... found 1

# %% [markdown]
# ## Generate the surface mesh
#
# First we'll generate the flattened, 2D triangulation, which builds on hydrography data.  Then we download a digital elevation map from the National Elevation Dataset, and extrude that 2D triangulation to a 3D surface mesh based on interpolation between pixels of the DEM.

# %% [markdown]
# ### Get river network
#
# This will download the river network from the NHD Plus database, and simplify the network, constructing a tree-like data structure.

# %%
rivers = True
if rivers:
    # download/collect the river network within that shape's bounds
    _, reaches = workflow.get_reaches(sources['hydrography'], huc, 
                                      watershed.exterior().bounds, crs, crs)
    # simplify and prune rivers not IN the shape, constructing a tree-like data structure
    # for the river network
    rivers = workflow.simplify_and_prune(watershed, reaches, filter=True, simplify=simplify, 
                                         snap=False, cut_intersections=False,
                                         ignore_small_rivers=ignore_small_rivers,
                                         prune_by_area_fraction=prune_by_area_fraction)


else:
    rivers = list()
    workflow.split_hucs.simplify(watershed, simplify)
# Out:
# 2021-07-23 10:13:48,443 - root - INFO:
# 2021-07-23 10:13:48,444 - root - INFO: Loading Hydrography
# 2021-07-23 10:13:48,445 - root - INFO: ------------------------------
# 2021-07-23 10:13:48,445 - root - INFO: Loading streams in HUC 140200010204
# 2021-07-23 10:13:48,446 - root - INFO:          and/or bounds (-589129.2083284792, -364373.6464318802, -578347.216132635, -357432.470730077)
# 2021-07-23 10:13:48,448 - root - INFO:   Using Hydrography file "/Users/uec/code/watershed_workflow/data-library/hydrography/NHDPlus_H_1402_GDB/NHDPlus_H_1402.gdb"
# 2021-07-23 10:13:48,449 - root - INFO:   National Hydrography Dataset Plus High Resolution (NHDPlus HR): opening '/Users/uec/code/watershed_workflow/data-library/hydrography/NHDPlus_H_1402_GDB/NHDPlus_H_1402.gdb' layer 'NHDFlowline' for streams in '(-589129.2083284792, -364373.6464318802, -578347.216132635, -357432.470730077)'
# /Users/uec/code/watershed_workflow/repos/master/workflow/sources/manager_nhd.py:171: RuntimeWarning: Sequential read of iterator was interrupted. Resetting iterator. This can negatively impact the performance.
#   reaches = [r for (i,r) in fid.items(bbox=bounds)]
# 2021-07-23 10:13:49,263 - root - INFO:   Filtering reaches not in-network
# 2021-07-23 10:13:49,264 - root - INFO:   National Hydrography Dataset Plus High Resolution (NHDPlus HR): opening '/Users/uec/code/watershed_workflow/data-library/hydrography/NHDPlus_H_1402_GDB/NHDPlus_H_1402.gdb' layer 'NHDPlusCatchment' for catchment areas in '(-107.10930056794344, 38.82619734938229, -106.97281504327864, 38.899907230233595)'
# 2021-07-23 10:13:52,171 - fiona._env - WARNING: organizePolygons() received a polygon with more than 100 parts.  The processing may be really slow.  You can skip the processing by setting METHOD=SKIP.
# 2021-07-23 10:13:57,724 - root - INFO: ... found 226 reaches
# 2021-07-23 10:13:57,725 - root - INFO: Converting to shapely
# 2021-07-23 10:13:57,749 - root - INFO: Converting to out_crs
# 2021-07-23 10:14:03,029 - root - INFO:
# 2021-07-23 10:14:03,029 - root - INFO: Simplifying and pruning
# 2021-07-23 10:14:03,030 - root - INFO: ------------------------------
# 2021-07-23 10:14:03,030 - root - INFO: Filtering rivers outside of the HUC space
# 2021-07-23 10:14:03,032 - root - INFO:   ...filtering
# 2021-07-23 10:14:03,053 - root - INFO: ... filtered from 226 to 118 reaches.
# 2021-07-23 10:14:03,054 - root - INFO: Generating the river tree
# 2021-07-23 10:14:03,066 - root - INFO: Removing rivers with fewer than 2 reaches.
# 2021-07-23 10:14:03,066 - root - INFO:   ...removing river with 1 reaches
# 2021-07-23 10:14:03,067 - root - INFO:   ...keeping river with 117 reaches
# 2021-07-23 10:14:03,067 - root - INFO: Simplifying rivers
# 2021-07-23 10:14:03,077 - root - INFO:   ...cleaned inner segment of length 20.0969 at centroid (-581044.3491645536, -360451.85253939126)
# 2021-07-23 10:14:03,078 - root - INFO:   ...cleaned inner segment of length 45.9157 at centroid (-583711.1774244647, -361018.0974516802)
# 2021-07-23 10:14:03,079 - root - INFO:   ...cleaned inner segment of length 74.4794 at centroid (-584363.7384295501, -361202.88008213334)
# 2021-07-23 10:14:03,082 - root - INFO: Simplifying HUCs
# 2021-07-23 10:14:03,083 - root - INFO: Pruning by fractional contributing area < 0.03
# 2021-07-23 10:14:03,085 - root - INFO: ... total contributing area = 48487009.38874754
# 2021-07-23 10:14:03,085 - root - INFO: ... removing: 435869.33192849526 of 48487009.38874754
# 2021-07-23 10:14:03,086 - root - INFO: ... removing: 447675.25994002173 of 48487009.38874754
# 2021-07-23 10:14:03,087 - root - INFO: ... removing: 331435.29338571406 of 48487009.38874754
# 2021-07-23 10:14:03,088 - root - INFO: ... removing: 759267.6019925565 of 48487009.38874754
# 2021-07-23 10:14:03,088 - root - INFO: ... removing: 165269.0529112907 of 48487009.38874754
# 2021-07-23 10:14:03,089 - root - INFO: ... removing: 354481.50587943796 of 48487009.38874754
# 2021-07-23 10:14:03,089 - root - INFO: ... removing: 767672.3597068675 of 48487009.38874754
# 2021-07-23 10:14:03,090 - root - INFO: ... removing: 529453.8639391036 of 48487009.38874754
# 2021-07-23 10:14:03,091 - root - INFO: ... removing: 872553.2916436814 of 48487009.38874754
# 2021-07-23 10:14:03,091 - root - INFO: ... removing: 559660.9135871012 of 48487009.38874754
# 2021-07-23 10:14:03,092 - root - INFO: ... removing: 329267.63823283266 of 48487009.38874754
# 2021-07-23 10:14:03,092 - root - INFO: ... removing: 169388.2856419007 of 48487009.38874754
# 2021-07-23 10:14:03,093 - root - INFO: ... removing: 234601.46757174298 of 48487009.38874754
# 2021-07-23 10:14:03,094 - root - INFO: ... removing: 120365.2341150529 of 48487009.38874754
# 2021-07-23 10:14:03,094 - root - INFO: ... removing: 894604.6756718322 of 48487009.38874754
# 2021-07-23 10:14:03,095 - root - INFO: ... removing: 359089.23088101536 of 48487009.38874754
# 2021-07-23 10:14:03,095 - root - INFO: ... removing: 665912.402381639 of 48487009.38874754
# 2021-07-23 10:14:03,096 - root - INFO: ... removing: 50393.87608903037 of 48487009.38874754
# 2021-07-23 10:14:03,096 - root - INFO: ... removing: 413575.4048440128 of 48487009.38874754
# 2021-07-23 10:14:03,097 - root - INFO: ... removing: 488830.73210762953 of 48487009.38874754
# 2021-07-23 10:14:03,097 - root - INFO: ... removing: 353932.77985540085 of 48487009.38874754
# 2021-07-23 10:14:03,098 - root - INFO: ... removing: 73713.40539789037 of 48487009.38874754
# 2021-07-23 10:14:03,099 - root - INFO: ... removing: 305646.07134248246 of 48487009.38874754
# 2021-07-23 10:14:03,099 - root - INFO: ... removing: 278472.70637963933 of 48487009.38874754
# 2021-07-23 10:14:03,100 - root - INFO: ... removing: 102426.5267077052 of 48487009.38874754
# 2021-07-23 10:14:03,100 - root - INFO: ... removing: 134069.10760700874 of 48487009.38874754
# 2021-07-23 10:14:03,101 - root - INFO: ... removing: 475188.1093736823 of 48487009.38874754
# 2021-07-23 10:14:03,101 - root - INFO: ... removing: 368014.0621961951 of 48487009.38874754
# 2021-07-23 10:14:03,102 - root - INFO: ... removing: 315253.34821462136 of 48487009.38874754
# 2021-07-23 10:14:03,102 - root - INFO: ... removing: 94117.25108870813 of 48487009.38874754
# 2021-07-23 10:14:03,103 - root - INFO: ... removing: 344548.0378747669 of 48487009.38874754
# 2021-07-23 10:14:03,103 - root - INFO: ... removing: 858339.7193143684 of 48487009.38874754
# 2021-07-23 10:14:03,104 - root - INFO: ... removing: 1013324.3500103535 of 48487009.38874754
# 2021-07-23 10:14:03,104 - root - INFO: ... removing: 1302742.8710406786 of 48487009.38874754
# 2021-07-23 10:14:03,105 - root - INFO: ... removing: 1357262.224777481 of 48487009.38874754
# 2021-07-23 10:14:03,106 - root - INFO: ... removing: 513674.4718258616 of 48487009.38874754
# 2021-07-23 10:14:03,106 - root - INFO: ... removing: 321321.20392015495 of 48487009.38874754
# 2021-07-23 10:14:03,107 - root - INFO: ... removing: 277688.0640849911 of 48487009.38874754
# 2021-07-23 10:14:03,107 - root - INFO: ... removing: 796557.7185332812 of 48487009.38874754
# 2021-07-23 10:14:03,108 - root - INFO: ... removing: 455619.44277175056 of 48487009.38874754
# 2021-07-23 10:14:03,108 - root - INFO: ... removing: 181079.46274227367 of 48487009.38874754
# 2021-07-23 10:14:03,109 - root - INFO: ... removing: 425000.5156054209 of 48487009.38874754
# 2021-07-23 10:14:03,109 - root - INFO: ... removing: 458567.8217524003 of 48487009.38874754
# 2021-07-23 10:14:03,110 - root - INFO: ... removing: 318453.8228537624 of 48487009.38874754
# 2021-07-23 10:14:03,110 - root - INFO: ... removing: 99140.4762315141 of 48487009.38874754
# 2021-07-23 10:14:03,111 - root - INFO: ... removing: 53961.35719536785 of 48487009.38874754
# 2021-07-23 10:14:03,111 - root - INFO: ... removing: 3201.0930782382534 of 48487009.38874754
# 2021-07-23 10:14:03,112 - root - INFO: ... removing: 25425.95104788122 of 48487009.38874754
# 2021-07-23 10:14:03,113 - root - INFO: ... removing: 1344494.5067125077 of 48487009.38874754
# 2021-07-23 10:14:03,113 - root - INFO: ... removing: 836057.4661283474 of 48487009.38874754
# 2021-07-23 10:14:03,114 - root - INFO: ... removing: 484840.22127408243 of 48487009.38874754
# 2021-07-23 10:14:03,114 - root - INFO: ... removing: 114877.41640318687 of 48487009.38874754
# 2021-07-23 10:14:03,115 - root - INFO: ... removing: 91918.00193285086 of 48487009.38874754
# 2021-07-23 10:14:03,116 - root - INFO: ... removing: 98227.8128181155 of 48487009.38874754
# 2021-07-23 10:14:03,116 - root - INFO: ... removing: 694370.0069405247 of 48487009.38874754
# 2021-07-23 10:14:03,117 - root - INFO: ... removing: 515195.5917952791 of 48487009.38874754
# 2021-07-23 10:14:03,117 - root - INFO: ... removing: 580186.9907251546 of 48487009.38874754
# 2021-07-23 10:14:03,118 - root - INFO: ... removing: 99501.35824469179 of 48487009.38874754
# 2021-07-23 10:14:03,118 - root - INFO: ... removing: 575651.0620277285 of 48487009.38874754
# 2021-07-23 10:14:03,119 - root - INFO: ... removing: 85976.87547314279 of 48487009.38874754
# 2021-07-23 10:14:03,119 - root - INFO: ... removing: 261131.99251191344 of 48487009.38874754
# 2021-07-23 10:14:03,120 - root - INFO: ... removing: 415696.77487098105 of 48487009.38874754
# 2021-07-23 10:14:03,120 - root - INFO: ... removing: 960003.0606779414 of 48487009.38874754
# 2021-07-23 10:14:03,121 - root - INFO: ... removing: 673356.6391414922 of 48487009.38874754
# 2021-07-23 10:14:03,121 - root - INFO: ... removing: 11707.259395429417 of 48487009.38874754
# 2021-07-23 10:14:03,122 - root - INFO: ... removing: 517046.23758733936 of 48487009.38874754
# 2021-07-23 10:14:03,123 - root - INFO: ... removing: 466284.0556288332 of 48487009.38874754
# 2021-07-23 10:14:03,123 - root - INFO: ... removing: 235427.4000897093 of 48487009.38874754
# 2021-07-23 10:14:03,124 - root - INFO: ... removing: 306825.8202118405 of 48487009.38874754
# 2021-07-23 10:14:03,124 - root - INFO: ... removing: 966924.0491623331 of 48487009.38874754
# 2021-07-23 10:14:03,125 - root - INFO: ... removing: 341755.67999101226 of 48487009.38874754
# 2021-07-23 10:14:03,126 - root - INFO: ... removing: 76453.45789896569 of 48487009.38874754
# 2021-07-23 10:14:03,128 - root - INFO: ... pruned 72
# 2021-07-23 10:14:03,128 - root - INFO:
# 2021-07-23 10:14:03,129 - root - INFO: Simplification Diagnostics
# 2021-07-23 10:14:03,129 - root - INFO: ------------------------------
# 2021-07-23 10:14:03,136 - root - INFO:   river min seg length: 87.04074690892794
# 2021-07-23 10:14:03,139 - root - INFO:   river median seg length: 366.76978066908816
# 2021-07-23 10:14:03,142 - root - INFO:   HUC min seg length: 171.08216114759398
# 2021-07-23 10:14:03,143 - root - INFO:   HUC median seg length: 171.08216114759398

# %%
# plot what we have so far -- an image of the HUC and its stream network
fig, ax = workflow.plot.get_ax(crs)

workflow.plot.hucs(watershed, crs, ax=ax, color='k', linewidth=1)
workflow.plot.rivers(rivers, crs, ax=ax, color='red', linewidth=1)
fig.savefig(f'../images/{name}_geometry')
# Out:
# /Users/Shared/ornldev/code/miniconda3/envs/watershed_workflow_20210603/lib/python3.9/site-packages/pyproj/crs/crs.py:543: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj_string = self.to_proj4()

# %% [markdown]
# ### Generate meshes using river network and watershed shape
#
# Triangulation refinement: refine triangles if their area (in m^2) is greater than A(d), where d is the
# distance from the triangle centroid to the nearest stream.  A(d) is a piecewise linear function -- A = A0 if d <= d0, A = A1 if d >= d1, and linearly interpolates between the two endpoints.

# %%
d0 = 100; d1 = 500
A0 = 8000; A1 = 50000 # [100, 310]m

# Refine triangles if they get too acute
min_angle = 32 # degrees

# make 2D mesh
mesh_points2, mesh_tris, areas, distances = workflow.triangulate(watershed, rivers, 
                                               refine_distance=[d0,A0,d1,A1],
                                               refine_min_angle=min_angle,
                                               diagnostics=True,
                                               )
# Out:
# 2021-07-23 10:14:03,428 - root - INFO:
# 2021-07-23 10:14:03,429 - root - INFO: Meshing
# 2021-07-23 10:14:03,430 - root - INFO: ------------------------------
# 2021-07-23 10:14:03,444 - root - INFO: Triangulating...
# 2021-07-23 10:14:03,445 - root - INFO:    57 points and 57 facets
# 2021-07-23 10:14:03,445 - root - INFO:  checking graph consistency
# 2021-07-23 10:14:03,446 - root - INFO:  tolerance is set to 1
# 2021-07-23 10:14:03,447 - root - INFO:  building graph data structures
# 2021-07-23 10:14:03,449 - root - INFO:  triangle.build...
# 2021-07-23 10:14:04,517 - root - INFO:   ...built: 2306 mesh points and 4448 triangles
# 2021-07-23 10:14:04,518 - root - INFO: Plotting triangulation diagnostics
# 2021-07-23 10:14:04,784 - root - INFO:   min area = 2597.317398071289
# 2021-07-23 10:14:04,785 - root - INFO:   max area = 49191.22822570801

# %% [markdown]
# ### Map mesh to DEM
#
# Download a DEM from USGS NED and elevate the triangle nodes to the DEM.

# %%
# download the needed rasters
dem_profile, dem = workflow.get_raster_on_shape(sources['DEM'], watershed.exterior(), crs)
# Out:
# 2021-07-23 10:14:04,968 - root - INFO:
# 2021-07-23 10:14:04,968 - root - INFO: Loading Raster
# 2021-07-23 10:14:04,969 - root - INFO: ------------------------------
# 2021-07-23 10:14:04,973 - root - INFO: Collecting raster
# 2021-07-23 10:14:04,996 - root - INFO: Collecting DEMs to tile bounds: [-107.11634327439819, 38.81770288243979, -106.96736783084837, 38.90466788650249]
# 2021-07-23 10:14:04,998 - root - INFO:   Need:
# 2021-07-23 10:14:04,999 - root - INFO:     /Users/uec/code/watershed_workflow/data-library/dem/USGS_NED_1as_n39_w108.tif
# 2021-07-23 10:14:05,000 - root - INFO:     /Users/uec/code/watershed_workflow/data-library/dem/USGS_NED_1as_n39_w107.tif
# 2021-07-23 10:14:05,001 - root - INFO: source files already exist!
# 2021-07-23 10:14:05,051 - root - INFO: ... got raster of shape: (314, 537)
# 2021-07-23 10:14:05,059 - root - INFO: ... got raster bounds: (-107.11634327439819, 38.90466788650249, -106.96717660772657, 38.81744566419919)

# %%
# noting that the DEM is a 30m raster, and we want to run at a coarser resolution of ~100-300m, 
# the DEM will look quite rough.  Smooth a small amount.  Note better algorithms could be used 
# here, but for now we just use Gaussian smoothing.
dem_sm = scipy.ndimage.gaussian_filter(dem, 5, mode='nearest')

fig, axs = plt.subplots(1,2, figsize=(10,5))
axs[0].imshow(dem)
axs[0].set_title('unsmoothed')
axs[1].imshow(dem_sm)
txt = axs[1].set_title('smoothed')

# %%
# elevate the x,y points onto the DEM to get a z coordinate
mesh_points3 = workflow.elevate(mesh_points2, crs, dem_sm, dem_profile)
# Out:
# 2021-07-23 10:14:05,283 - root - INFO:
# 2021-07-23 10:14:05,284 - root - INFO: Elevating Triangulation to DEM
# 2021-07-23 10:14:05,285 - root - INFO: ------------------------------

# %%
# construct the 2D mesh
m2 = workflow.mesh.Mesh2D(mesh_points3.copy(), list(mesh_tris))

# %%
def edge_height(e):
    return (m2.coords[e[0],2] + m2.coords[e[1],2])/2
print(min(edge_height(e) for e in m2.boundary_edges()))
# Out:
# 2705.526315603425

# %%
# hydrologically condition the mesh, removing pits
workflow.condition.fill_pits(m2)

# %%
# plot the resulting surface mesh
fig, ax = workflow.plot.get_ax(crs, window=[0.05,0.1,0.9,0.8])
cbax = fig.add_axes([0.05,0.05,0.9,0.05])

mp = workflow.plot.triangulation(m2.coords, m2.conn, crs, ax=ax, 
                                 color='elevation', edgecolor='white', linewidth=0.2)
cbar = fig.colorbar(mp, orientation="horizontal", cax=cbax)
workflow.plot.hucs(watershed, crs, ax=ax, color='k', linewidth=1)
workflow.plot.rivers(rivers, crs, ax=ax, color='red', linewidth=1)
ax.set_aspect('equal', 'datalim')
txt = cbar.ax.set_xlabel('elevation [m]', loc='center')
fig.savefig(f'../images/{name}_dem')

# %% [markdown]
# ## Surface properties
#
# Meshes interact with data to provide forcing, parameters, and more in the actual simulation.  Specifically, we need vegetation type on the surface to provide information about transpiration and subsurface structure to provide information about water retention curves, etc.
#
# We'll start by downloading and collecting land cover from the NLCD dataset, and generate sets for each land cover type that cover the surface.  Likely these will be some combination of grass, deciduous forest, coniferous forest, and mixed forest.

# %%
# download the NLCD raster
lc_profile, lc_raster = workflow.get_raster_on_shape(sources['land cover'], 
                                                     watershed.exterior(), crs)

# resample the raster to the triangles
lc = workflow.values_from_raster(m2.centroids(), crs, lc_raster, lc_profile)

# what land cover types did we get?
logging.info('Found land cover dtypes: {}'.format(lc.dtype))
logging.info('Found land cover types: {}'.format(set(lc)))
# Out:
# 2021-07-23 10:14:05,857 - root - INFO:
# 2021-07-23 10:14:05,858 - root - INFO: Loading Raster
# 2021-07-23 10:14:05,859 - root - INFO: ------------------------------
# 2021-07-23 10:14:05,860 - root - INFO: Collecting raster
# 2021-07-23 10:14:05,874 - root - INFO: CRS: PROJCS["Albers_Conical_Equal_Area",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["latitude_of_center",23],PARAMETER["longitude_of_center",-96],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["meters",1],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# 2021-07-23 10:14:05,943 - root - INFO: ... got raster of shape: (245, 374)
# 2021-07-23 10:14:05,953 - root - INFO: ... got raster bounds: (-952575.0, 1818405.0, -941355.0, 1811055.0)
# 2021-07-23 10:14:06,083 - root - INFO: Found land cover dtypes: uint8
# 2021-07-23 10:14:06,084 - root - INFO: Found land cover types: {71, 41, 42, 11, 43, 81, 52, 21, 22, 23, 90, 31, 95}

# %%
# plot the image
# -- get the NLCD colormap which uses official NLCD colors and labels
nlcd_indices, nlcd_cmap, nlcd_norm, nlcd_ticks, nlcd_labels = \
                workflow.colors.generate_nlcd_colormap(lc)

fig, ax = workflow.plot.get_ax(crs)
polys = workflow.plot.mesh(m2, crs, ax=ax, color=lc, cmap=nlcd_cmap, norm=nlcd_norm, edgecolor='none', 
                                     facecolor='color', linewidth=0.5)

workflow.colors.colorbar_index(ncolors=len(np.unique(lc)), cmap=nlcd_cmap, labels = nlcd_labels) 

ax.set_title("Land Cover Index")
ext = ax.axis('off')
fig.savefig(f'../images/{name}_land_cover_raw')

# %%
# we don't really need all of these.  Keep Evergreen, Deciduous, Shrub, and merge the rest into "Other"
nlcd_color_new = 99 * np.ones_like(lc)

groupings = {
    42 : ['Evergreen Forest',],
    41 : ['Deciduous Forest', 'Mixed Forest', 'Woody Wetlands'],
    52 : ['Dwarf Scrub', 'Shrub/Scrub', 'Grassland/Herbaceous', 'Sedge/Herbaceous', 
                     'Pasture/Hay', 'Cultivated Crops'],
}

for k,v in groupings.items():
    for label in v:
        index = sources['land cover'].indices[label]
        nlcd_color_new[np.where(lc == index)] = k
    
print(nlcd_color_new)
# Out:
# [99 99 99 ... 42 42 42]

# %%
# plot the updated image, adding "other"
nlcd_color_new_other_as_water = np.where(nlcd_color_new == 99, 11, nlcd_color_new)

# -- get the NLCD colormap which uses official NLCD colors and labels
nlcd_indices, nlcd_cmap, nlcd_norm, nlcd_ticks, nlcd_labels = \
                workflow.colors.generate_nlcd_colormap(nlcd_color_new_other_as_water)

# make (water, 11) into (other, 99)
nlcd_labels[0] = 'Other'
nlcd_indices[0] = 99

fig, ax = workflow.plot.get_ax(crs)


polys = workflow.plot.mesh(m2, crs, ax=ax, color=nlcd_color_new_other_as_water, 
                           cmap=nlcd_cmap, norm=nlcd_norm, edgecolor='none', 
                        facecolor='color', linewidth=0.5)

workflow.colors.colorbar_index(ncolors=len(np.unique(nlcd_color_new_other_as_water)), 
                               cmap=nlcd_cmap, labels = nlcd_labels) 

ax.set_title("Land Cover Index")
ext = ax.axis('off')
fig.savefig(f'../images/{name}_land_cover')

# %% [markdown]
# ## Subsurface properties
#
# The default model uses GLHYMPS to identify geologic formations, and

# %%
# download the NRCS soils data as shapes and project it onto the mesh

# -- download the shapes
target_bounds = watershed.exterior().bounds
logging.info('target bounds: {}'.format(target_bounds))
soil_profile, soil_survey, soil_survey_props = workflow.get_shapes(sources['soil structure'], 
                                                                   target_bounds, crs, crs, properties=True)

# -- determine the NRCS mukey for each soil unit; this uniquely identifies soil 
#    properties
soil_ids = np.array([shp.properties['mukey'] for shp in soil_survey], np.int32)

# -- color a raster by the polygons (this makes identifying a triangle's value much 
#    more efficient)
soil_color_raster, soil_color_profile, img_bounds = \
            workflow.color_raster_from_shapes(target_bounds, 10, soil_survey,
                                              soil_ids, crs)

# -- resample the raster to the triangles
soil_color = workflow.values_from_raster(m2.centroids(), crs, 
                                         soil_color_raster, soil_color_profile)
# Out:
# 2021-07-23 10:14:08,488 - root - INFO: target bounds: (-589129.2083284792, -364373.6464318802, -578347.216132635, -357432.470730077)
# 2021-07-23 10:14:08,489 - root - INFO:
# 2021-07-23 10:14:08,490 - root - INFO: Loading shapes
# 2021-07-23 10:14:08,491 - root - INFO: ------------------------------
# 2021-07-23 10:14:08,544 - root - INFO: Attempting to download source for target '/Users/uec/code/watershed_workflow/data-library/soil_structure/SSURGO/SSURGO_-107.1094_38.8261_-106.9727_38.9000.shp'
# 2021-07-23 10:14:08,613 - root - INFO:   Found 135 shapes.
# 2021-07-23 10:14:08,623 - root - INFO:   and crs: +init=epsg:4326 +type=crs
# 2021-07-23 10:14:08,645 - root - INFO: found 39 unique MUKEYs.
# 2021-07-23 10:14:10,613 - root - INFO: Running Rosetta for van Genutchen parameters
# 2021-07-23 10:14:10,614 - root - INFO:   database: /Users/uec/code/watershed_workflow/repos/master/workflow_tpls/rosetta/sqlite/rosetta.sqlite
# 2021-07-23 10:14:10,614 - root - INFO:   model type: 3
# 2021-07-23 10:14:10,785 - root - INFO:   ... done
# 2021-07-23 10:14:10,800 - root - INFO: ... found 135 shapes
# 2021-07-23 10:14:10,801 - root - INFO: Converting to shapely
# 2021-07-23 10:14:10,826 - root - INFO: Converting to requested CRS
# 2021-07-23 10:14:10,869 - root - INFO: Coloring shapes onto raster:
# 2021-07-23 10:14:10,870 - root - INFO:   target_bounds = (-589129.2083284792, -364373.6464318802, -578347.216132635, -357432.470730077)
# 2021-07-23 10:14:10,870 - root - INFO:   out_bounds = [-589134.0, -364377.0, -578334.0, -357427.0]
# 2021-07-23 10:14:10,871 - root - INFO:   pixel_size = 10
# 2021-07-23 10:14:10,872 - root - INFO:   width = 1080, height = 695
# 2021-07-23 10:14:10,872 - root - INFO:   and 39 independent colors of dtype int32

# %% [markdown]
# Select only the soils within the watershed

# %%
soil_survey_props.set_index('mukey', inplace=True, drop=False)
soil_survey_props = soil_survey_props.loc[np.unique(soil_color), :]

# %%
# plot the soil mukey
indices, cmap, norm, ticks, labels = workflow.colors.generate_indexed_colormap(soil_color, cmap='tab20c')
fig, ax = workflow.plot.get_ax(crs)

mp = workflow.plot.mesh(m2, crs, ax=ax, facecolor='color',
                        linewidth=0, color=soil_color, 
                        cmap=cmap, norm = norm
                       )

workflow.colors.colorbar_index(ncolors=len(np.unique(soil_color)), cmap=cmap, labels = labels) 

ax.set_title('soil type index')
ax.axis('off')
# Out:
# /Users/Shared/ornldev/code/miniconda3/envs/watershed_workflow_20210603/lib/python3.9/site-packages/pyproj/crs/crs.py:543: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj_string = self.to_proj4()
# (-589668.3076, -577808.1164, -364720.70475000003, -357085.41225)

# %%
# what does soil thickness look like?
soil_thickness = np.empty(soil_color.shape, 'd')
for mukey in soil_survey_props.index:
    soil_thickness[soil_color == mukey] = soil_survey_props.loc[mukey,'thickness [cm]']

soil_thickness = soil_thickness / 100
fig, ax = workflow.plot.get_ax(crs)
mp = workflow.plot.triangulation(mesh_points3, mesh_tris, crs, ax=ax, 
                                 color=soil_thickness, edgecolor='gray', cmap='jet')
ax.set_title('soil thickness [m]')
cb = fig.colorbar(mp, fraction=0.04, pad=0.04)
ax.axis('off')

print('Median soil thickness [-] = ', np.nanmedian(soil_thickness))
# Out:
# Median soil thickness [-] =  1.52

# %%
# plot of porosity from SSURGO
iprop = np.empty(soil_color.shape, 'd')
for mukey in soil_survey_props.index:
    iprop[soil_color == mukey] = soil_survey_props.loc[ mukey,'porosity [-]']

fig, ax = workflow.plot.get_ax(crs)
mp = workflow.plot.triangulation(mesh_points3, mesh_tris, crs, ax=ax, 
                                 color=iprop, edgecolor='gray', cmap='jet')
ax.set_title('soil porosity [-]')
cb = fig.colorbar(mp, fraction=0.04, pad=0.04, extend = "both", shrink = 0.6)
ax.axis('off')

print('Median porosity [-] = ', np.nanmedian(iprop))
fig.savefig(f'../images/{name}_soil_porosity')
# Out:
# Median porosity [-] =  0.19334978070175438

# %%
# plot of permeability
iprop = np.empty(soil_color.shape, 'd')
for mukey in soil_survey_props.index:
    iprop[soil_color == mukey] = soil_survey_props.loc[ mukey,'permeability [m^2]']

fig, ax = workflow.plot.get_ax(crs)
mp = workflow.plot.triangulation(mesh_points3, mesh_tris, crs, ax=ax, 
                                 color=np.log10(iprop), edgecolor='gray', cmap='jet')
ax.set_title('soil permeability [-]')
cb = fig.colorbar(mp, fraction=0.04, pad=0.04, extend = "both", shrink = 0.6)
cb.ax.set_title('log K')
ax.axis('off')

print('Min k [m^2] = ', np.nanmin(iprop))
fig.savefig(f'../images/{name}_soil_permeability')
# Out:
# Min k [m^2] =  7.0000000000000025e-15

# %%
# Note the missing data (white).  This is because some SSURGO map units have no formation with complete 
# information.  So we merge the above available data, filling where possible and dropping regions that
# do not have a complete set of properties.
soil_survey_props_clean = soil_survey_props.copy()

# later scripts expect 'native_index' as a standard name of holding onto the original IDs
soil_survey_props_clean.rename_axis('native_index', inplace=True)
soil_survey_props_clean.rename(columns={'mukey':'native_index'}, inplace=True)

# need thickness in m
soil_survey_props_clean['thickness [cm]'] = soil_survey_props_clean['thickness [cm]']/100.
soil_survey_props_clean.rename(columns={'thickness [cm]':'thickness [m]'}, inplace=True)


def replace_column_nans(df, col_nan, col_replacement):
    """In a df, replace col_nan entries by col_replacement if is nan.  In Place!"""
    row_indexer = df[col_nan].isna()
    df.loc[row_indexer, col_nan] = df.loc[row_indexer, col_replacement]
    return

# where poro or perm is nan, put Rosetta poro
replace_column_nans(soil_survey_props_clean, 'porosity [-]', 'Rosetta porosity [-]')
replace_column_nans(soil_survey_props_clean, 'permeability [m^2]', 'Rosetta permeability [m^2]')

# drop unnecessary columns
for col in ['Rosetta porosity [-]', 'Rosetta permeability [m^2]', 'bulk density [g/cm^3]', 'total sand pct [%]',
            'total silt pct [%]', 'total clay pct [%]']:
    soil_survey_props_clean.pop(col)
    
# drop nans
soil_survey_props_clean.dropna(inplace=True)
soil_survey_props_clean.reset_index(drop=True, inplace=True)
soil_survey_props_clean
# Out:
#     residual saturation [-]  van Genuchten alpha [Pa^-1]  van Genuchten n [-]  \
# 0                  0.240269                     0.000092             1.319916
# 1                  0.181598                     0.000139             1.457559
# 2                  0.181598                     0.000139             1.457559
# 3                  0.208316                     0.000071             1.420938
# 4                  0.213285                     0.000059             1.416784
# 5                  0.175133                     0.000103             1.383180
# 6                  0.230885                     0.000079             1.374540
# 7                  0.230885                     0.000079             1.374540
# 8                  0.207877                     0.000092             1.397760
# 9                  0.219597                     0.000072             1.395746
# 10                 0.241801                     0.000079             1.340429
# 11                 0.196811                     0.000157             1.406091
# 12                 0.199783                     0.000087             1.422578
# 13                 0.189314                     0.000104             1.433685
# 14                 0.210870                     0.000078             1.410010
# 15                 0.246665                     0.000081             1.332817
# 16                 0.157366                     0.000221             1.762072
# 17                 0.220962                     0.000140             1.367408
#
#     native_index  thickness [m]  permeability [m^2]  porosity [-] source
# 0         498185       1.520000        2.279759e-13      0.265563   NRCS
# 1         498205       1.520000        2.734080e-12      0.159737   NRCS
# 2         498206       1.520000        2.734080e-12      0.159737   NRCS
# 3         498208       1.520000        1.184189e-12      0.185986   NRCS
# 4         498231       1.070000        7.331979e-13      0.403218   NRCS
# 5         509477       1.520000        3.039095e-12      0.428779   NRCS
# 6         509479       1.250000        3.172415e-12      0.378365   NRCS
# 7         509481       1.250000        3.172415e-12      0.378365   NRCS
# 8         509482       1.205000        4.654687e-12      0.369886   NRCS
# 9         509513       1.520000        9.122162e-13      0.237423   NRCS
# 10        509514       1.520000        2.375523e-13      0.271630   NRCS
# 11        509529       1.520000        5.850942e-12      0.356163   NRCS
# 12        509532       1.520000        1.526682e-12      0.182238   NRCS
# 13        509548       1.520000        2.006536e-12      0.193350   NRCS
# 14        509559       0.618125        7.504374e-13      0.151250   NRCS
# 15        509561       1.396471        1.590777e-13      0.218625   NRCS
# 16        509733       0.860000        4.744971e-12      0.449752   NRCS
# 17        509794       1.520000        1.302800e-12      0.415245   NRCS

# %%
# create a new soil_color, keeping on those that are kept here and re-indexing to ATS indices
soil_color_new = -np.ones_like(soil_color)
for new_id, mukey in enumerate(soil_survey_props_clean['native_index']):
    soil_color_new[np.where(soil_color == mukey)] = 1000+new_id
    
# image the new soil_color
indices, cmap, norm, ticks, labels = workflow.colors.generate_indexed_colormap(soil_color_new, cmap='tab20c')
fig, ax = workflow.plot.get_ax(crs)

mp = workflow.plot.mesh(m2, crs, ax=ax, facecolor='color',
                        linewidth=0, color=soil_color_new, 
                        cmap=cmap, norm=norm)

workflow.colors.colorbar_index(ncolors=len(np.unique(soil_color_new)), cmap=cmap, labels=labels) 

ax.set_title('soil type index')
ax.axis('off')
fig.savefig(f'../images/{name}_soil_indices')
# Out:
# /Users/Shared/ornldev/code/miniconda3/envs/watershed_workflow_20210603/lib/python3.9/site-packages/pyproj/crs/crs.py:543: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj_string = self.to_proj4()

# %% [markdown]
# ### GLYHMPS geologic layer
#
# GLYHMPS is complete in that it does not appear to have missing data, but does not have texture properties needed for Water Retention Models.  Instead we rely on scaling laws to fill the data.

# %%
# extract the GLYHMPS geologic structure data as shapes and project it onto the mesh
target_bounds = watershed.exterior().bounds
logging.info('target bounds: {}'.format(target_bounds))

_, geo_survey, geo_survey_props = workflow.get_shapes(sources['geologic structure'], 
                                                      target_bounds, crs, crs, properties=True)

# -- log the bounds targeted and found
logging.info('shape union bounds: {}'.format(
    shapely.ops.cascaded_union(geo_survey).bounds))

# -- determine the ID for each soil unit; this uniquely identifies formation
#    properties
geo_ids = np.array([shp.properties['id'] for shp in geo_survey], np.int32)

# -- color a raster by the polygons (this makes identifying a triangle's value much 
#    more efficient)
geo_color_raster, geo_color_profile, img_bounds = \
            workflow.color_raster_from_shapes(target_bounds, 10, geo_survey,
                                              geo_ids, crs)

# -- resample the raster to the triangles
geo_color = workflow.values_from_raster(m2.centroids(), crs, 
                                         geo_color_raster, geo_color_profile)
# Out:
# 2021-07-23 10:14:14,524 - root - INFO: target bounds: (-589129.2083284792, -364373.6464318802, -578347.216132635, -357432.470730077)
# 2021-07-23 10:14:14,525 - root - INFO:
# 2021-07-23 10:14:14,526 - root - INFO: Loading shapes
# 2021-07-23 10:14:14,527 - root - INFO: ------------------------------
# 2021-07-23 10:14:14,527 - root - INFO: Getting shapes of GLHYMPS on bounds: (-589129.2083284792, -364373.6464318802, -578347.216132635, -357432.470730077)
# 2021-07-23 10:14:14,528 - root - INFO:   from file: /Users/uec/code/watershed_workflow/data-library/soil_structure/GLHYMPS/GLHYMPS.shp
# 2021-07-23 10:14:14,635 - fiona.ogrext - INFO: Failed to auto identify EPSG: 7
# /Users/uec/code/watershed_workflow/repos/master/workflow/sources/manager_shape.py:76: RuntimeWarning: Sequential read of iterator was interrupted. Resetting iterator. This can negatively impact the performance.
#   shps = [s for (i,s) in fid.items(bbox=bounds)]
# 2021-07-23 10:14:37,681 - root - INFO: ... found 19 shapes
# 2021-07-23 10:14:37,681 - root - INFO: Converting to shapely
# 2021-07-23 10:14:37,752 - root - INFO: Converting to requested CRS
# 2021-07-23 10:14:37,811 - root - INFO: shape union bounds: (-595334.679497647, -386597.7350209888, -568166.7194544679, -333924.17123101535)
# 2021-07-23 10:14:37,812 - root - INFO: Coloring shapes onto raster:
# 2021-07-23 10:14:37,812 - root - INFO:   target_bounds = (-589129.2083284792, -364373.6464318802, -578347.216132635, -357432.470730077)
# 2021-07-23 10:14:37,813 - root - INFO:   out_bounds = [-589134.0, -364377.0, -578334.0, -357427.0]
# 2021-07-23 10:14:37,814 - root - INFO:   pixel_size = 10
# 2021-07-23 10:14:37,814 - root - INFO:   width = 1080, height = 695
# 2021-07-23 10:14:37,815 - root - INFO:   and 19 independent colors of dtype int32

# %%
# select the properties that appear in the mesh
geo_survey_props.set_index('id', inplace=True, drop=False)
geo_survey_props = geo_survey_props.loc[np.unique(geo_color), :]

# %%
# plot the geologic formation id
indices, cmap, norm, ticks, labels = workflow.colors.generate_indexed_colormap(geo_color, cmap='tab20b')

fig, ax = workflow.plot.get_ax(crs)

mp = workflow.plot.mesh(m2, crs, ax=ax, facecolor='color',
                        linewidth=0, color=geo_color, 
                        cmap=cmap, norm=norm)

workflow.colors.colorbar_index(ncolors=len(np.unique(geo_color)), cmap=cmap, labels=labels) 

ax.set_title('geol type index')
ax.axis('off')
# Out:
# (-589668.3076, -577808.1164, -364720.70475000003, -357085.41225)

# %%
# plot permeability of the underlying geologic layer
iprop = np.empty(geo_color.shape, 'd')
for i in geo_survey_props.index:
    iprop[geo_color == i] = geo_survey_props.loc[i, 'permeability [m^2]']
    
fig, ax = workflow.plot.get_ax(crs)
mp = workflow.plot.triangulation(mesh_points3, mesh_tris, crs, ax=ax, 
                                 color=np.log10(iprop), edgecolor='gray', cmap='jet')
cbar = fig.colorbar(mp, shrink=0.5)
ax.set_title('geology log permeability [m^2]')
ax.axis('off')

fig.savefig(f'../images/{name}_geo_permeability')

# %%
# plot porosity of the geologic layer
iprop = np.empty(geo_color.shape, 'd')
for i in geo_survey_props.index:
    iprop[geo_color == i] = geo_survey_props.loc[i, 'porosity [-]']

fig, ax = workflow.plot.get_ax(crs)
mp = workflow.plot.triangulation(mesh_points3, mesh_tris, crs, ax=ax, 
                                 color=iprop, edgecolor='gray', cmap='jet')
cbar = fig.colorbar(mp, shrink=0.5)
ax.set_title('geology porosity [-]')
ax.axis('off')
fig.savefig(f'../images/{name}_geo_porosity')

# %%
# note there are clearly some common regions -- no need to duplicate those with identical values.
geo_survey_props_clean = geo_survey_props.copy()
geo_survey_props_clean.pop('logk_stdev [-]')
geo_survey_props_clean.rename(columns={'id':'native_index'}, inplace=True)


def reindex_remove_duplicates(df, index=None):
    """Removes duplicates, creating a new index and saving the old index as tuples of duplicate values. In place!"""
    if index is not None:
        if index in df:
            df.set_index(index, drop=True, inplace=True)
    
    index_name = df.index.name

    # identify duplicate rows
    duplicates = list(df.groupby(list(df)).apply(lambda x: tuple(x.index)))

    # order is preserved
    df.drop_duplicates(inplace=True)
    df.reset_index(inplace=True)
    df[index_name] = duplicates
    return

reindex_remove_duplicates(geo_survey_props_clean, 'native_index')
geo_survey_props_clean
# Out:
#                        native_index   source  permeability [m^2]  \
# 0  (715639, 715796, 726604, 726608)  GLHYMPS        6.309573e-16
# 1          (715779, 726642, 726664)  GLHYMPS        3.162278e-13
# 2          (715766, 726639, 726667)  GLHYMPS        1.000000e-13
# 3                         (730801,)  GLHYMPS        3.019952e-11
#
#    porosity [-]  van Genuchten alpha [Pa^-1]  van Genuchten n [-]  \
# 0          0.19                     0.000025                  2.0
# 1          0.09                     0.000775                  2.0
# 2          0.22                     0.000294                  2.0
# 3          0.01                     0.007574                  2.0
#
#    residual saturation [-]
# 0                     0.01
# 1                     0.01
# 2                     0.01
# 3                     0.01

# %%
# create a new geologic layer color, keeping on those that are kept here and re-indexing to ATS indices
geo_color_new = -np.ones_like(geo_color)
for new_id, old_id_dups in enumerate(geo_survey_props_clean['native_index']):
    for old_id in old_id_dups:
        geo_color_new[np.where(geo_color == old_id)] = 100+new_id
    
# image the new geo_color
indices, cmap, norm, ticks, labels = workflow.colors.generate_indexed_colormap(geo_color_new, cmap='tab20c')
fig, ax = workflow.plot.get_ax(crs)

mp = workflow.plot.mesh(m2, crs, ax=ax, facecolor='color',
                        linewidth=0, color=geo_color_new, 
                        cmap=cmap, norm=norm)

workflow.colors.colorbar_index(ncolors=len(np.unique(geo_color_new)), cmap=cmap, labels=labels) 

ax.set_title('geologic type index')
ax.axis('off')
fig.savefig(f'../images/{name}_geo_indices')
# Out:
# /Users/Shared/ornldev/code/miniconda3/envs/watershed_workflow_20210603/lib/python3.9/site-packages/pyproj/crs/crs.py:543: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj_string = self.to_proj4()

# %% [markdown]
# ## Depth-to-bedrock

# %% [markdown]
# Depth to bedrock is taken from the [SoilGrids](http://globalchange.bnu.edu.cn/research/dtb.jsp) product.  Here we download a US-based, clipped version of this global product, as file sizes are quite large (all products potentially used total over 100GB).

# %%
DTB_source = workflow.source_list.structure_sources['SoilGrids2017']
DTB_profile, DTB_raster = workflow.get_raster_on_shape(DTB_source, watershed.exterior(), crs, 
                                                       nodata=-99999, variable='BDTICM')

# resample the raster to the triangles
DTB_raster = DTB_raster/100 #convert from cm to m
DTB = workflow.values_from_raster(m2.centroids(), crs, DTB_raster, DTB_profile, algorithm='piecewise bilinear')
DTB = np.where(DTB >= 0, DTB, np.nan)
# Out:
# 2021-07-23 10:14:40,971 - root - INFO:
# 2021-07-23 10:14:40,972 - root - INFO: Loading Raster
# 2021-07-23 10:14:40,973 - root - INFO: ------------------------------
# 2021-07-23 10:14:40,974 - root - INFO: Collecting raster
# 2021-07-23 10:14:40,980 - root - INFO: CRS: EPSG:4326
# 2021-07-23 10:14:40,981 - root - INFO: filename: /Users/uec/code/watershed_workflow/data-library/soil_structure/SoilGrids2017_US/BDTICM_M_250m_ll_us.tif
# 2021-07-23 10:14:41,036 - root - INFO: ... got raster of shape: (33, 63)
# 2021-07-23 10:14:41,045 - root - INFO: ... got raster bounds: (-107.10833619599228, 38.895835029995425, -106.97708621699222, 38.82708504099539)
# bounds in my_crs: (-107.10634327439818, 38.82770288243979, -106.97736783084838, 38.89466788650249)

# %%
# plot the resulting surface mesh
fig, ax = workflow.plot.get_ax(crs, window=[0.05,0.1,0.9,0.8])
cbax = fig.add_axes([.95,0.1,0.05,0.8])

mp = workflow.plot.triangulation(mesh_points3, mesh_tris, crs, ax=ax, 
                                 color=DTB, cmap='plasma_r', edgecolor='white', linewidth=0.1)
cbar = fig.colorbar(mp, orientation="vertical", cax=cbax)
workflow.plot.hucs(watershed, crs, ax=ax, color='k', linewidth=1)

ax.set_aspect('equal', 'datalim')
ax.axis('off')

cbar.ax.set_title('DTB [m]')
fig.savefig(f'../images/{name}_dtb')

# %% [markdown]
# ## A combined, complete product?
#
# As a default, we would like a material-driven (e.g. not fields for porosity, perm, etc, but soil classes, each with a common porosity/permeability/vG curve) default that is valid everywhere.  That makes it clear that we must rely on GLHYMPS as the only material-based product that is valid everywhere.  Other products may be layered on top of this, replacing GLHYMPS values, but the underlying layer should be based on GLHYMPS.  To fill in the van Genuchten properties, we relate alpha to permeability and choose a single common n and s_r.
#
# Where available, we then choose to use SSURGO as a layer on top of GLHYMPS.  So start by using all GLHYMPS values, then override ones where SSURGO is valid with those values.  This will be the second model, and has then three layers -- a bedrock layer, a soil layer from 0 to 2m, and a geologic layer, using GLHYMPS values.  SoilGrids depth-to-bedrock will be used to provide the transition between bedrock and (where > 2m) the GLHYMPS "geologic" layer or (where < 2m) the SSURGO "soil" layer.  Where SSURGO has no values, the underlying GLHYMPS values will be used even in the top 2m.

# %% [markdown]
# Note, all integer IDs in mesh files must be unique.  This includes Material IDs, side sets, etc.  We create the Material ID map and data frame.  This is used to standardize IDs from multiple data sources.  Traditionally, ATS numbers Material IDs/Side Sets as:
#
# * 0-9 : reserved for boundaries, surface/bottom, etc
# * 10-99 : Land Cover side sets, typically NLCD IDs are used
# * 100-999 : geologic layer material IDs. 999 is reserved for bedrock.
# * 1000-9999 : soil layer material IDs

# %%
# map SSURGO mukey to ATS_ID
soil_survey_props_clean['ats_id'] = range(1000, 1000+len(soil_survey_props_clean))
soil_survey_props_clean.set_index('ats_id', inplace=True)

# map GLHYMPS id to ATS_ID
geo_survey_props_clean['ats_id'] = range(100, 100+len(geo_survey_props_clean))
geo_survey_props_clean.set_index('ats_id', inplace=True)

bedrock_props = workflow.soil_properties.get_bedrock_properties()

# merge the properties databases
subsurface_props = pandas.concat([geo_survey_props_clean,
                                  soil_survey_props_clean,
                                  bedrock_props])

# save the properties to disk for use in generating input file
outputs['subsurface_properties_filename'] = f'../data-processed/{name}_subsurface_properties.csv'
subsurface_props.to_csv(outputs['subsurface_properties_filename'])
subsurface_props
# Out:
#                             native_index   source  permeability [m^2]  \
# ats_id
# 100     (715639, 715796, 726604, 726608)  GLHYMPS        6.309573e-16
# 101             (715779, 726642, 726664)  GLHYMPS        3.162278e-13
# 102             (715766, 726639, 726667)  GLHYMPS        1.000000e-13
# 103                            (730801,)  GLHYMPS        3.019952e-11
# 1000                              498185     NRCS        2.279759e-13
# 1001                              498205     NRCS        2.734080e-12
# 1002                              498206     NRCS        2.734080e-12
# 1003                              498208     NRCS        1.184189e-12
# 1004                              498231     NRCS        7.331979e-13
# 1005                              509477     NRCS        3.039095e-12
# 1006                              509479     NRCS        3.172415e-12
# 1007                              509481     NRCS        3.172415e-12
# 1008                              509482     NRCS        4.654687e-12
# 1009                              509513     NRCS        9.122162e-13
# 1010                              509514     NRCS        2.375523e-13
# 1011                              509529     NRCS        5.850942e-12
# 1012                              509532     NRCS        1.526682e-12
# 1013                              509548     NRCS        2.006536e-12
# 1014                              509559     NRCS        7.504374e-13
# 1015                              509561     NRCS        1.590777e-13
# 1016                              509733     NRCS        4.744971e-12
# 1017                              509794     NRCS        1.302800e-12
# 999                                  NaN      n/a        1.000000e-16
#
#         porosity [-]  van Genuchten alpha [Pa^-1]  van Genuchten n [-]  \
# ats_id
# 100         0.190000                     0.000025             2.000000
# 101         0.090000                     0.000775             2.000000
# 102         0.220000                     0.000294             2.000000
# 103         0.010000                     0.007574             2.000000
# 1000        0.265563                     0.000092             1.319916
# 1001        0.159737                     0.000139             1.457559
# 1002        0.159737                     0.000139             1.457559
# 1003        0.185986                     0.000071             1.420938
# 1004        0.403218                     0.000059             1.416784
# 1005        0.428779                     0.000103             1.383180
# 1006        0.378365                     0.000079             1.374540
# 1007        0.378365                     0.000079             1.374540
# 1008        0.369886                     0.000092             1.397760
# 1009        0.237423                     0.000072             1.395746
# 1010        0.271630                     0.000079             1.340429
# 1011        0.356163                     0.000157             1.406091
# 1012        0.182238                     0.000087             1.422578
# 1013        0.193350                     0.000104             1.433685
# 1014        0.151250                     0.000078             1.410010
# 1015        0.218625                     0.000081             1.332817
# 1016        0.449752                     0.000221             1.762072
# 1017        0.415245                     0.000140             1.367408
# 999         0.150000                     0.000011             3.000000
#
#         residual saturation [-]  thickness [m]
# ats_id
# 100                    0.010000            NaN
# 101                    0.010000            NaN
# 102                    0.010000            NaN
# 103                    0.010000            NaN
# 1000                   0.240269       1.520000
# 1001                   0.181598       1.520000
# 1002                   0.181598       1.520000
# 1003                   0.208316       1.520000
# 1004                   0.213285       1.070000
# 1005                   0.175133       1.520000
# 1006                   0.230885       1.250000
# 1007                   0.230885       1.250000
# 1008                   0.207877       1.205000
# 1009                   0.219597       1.520000
# 1010                   0.241801       1.520000
# 1011                   0.196811       1.520000
# 1012                   0.199783       1.520000
# 1013                   0.189314       1.520000
# 1014                   0.210870       0.618125
# 1015                   0.246665       1.396471
# 1016                   0.157366       0.860000
# 1017                   0.220962       1.520000
# 999                    0.010000            NaN

# %%
# make a giant plot of all the WRMs
import plot_wrm # $ATS_SRC_DIR/tools/utils
fig = plt.figure()
ax = fig.add_subplot(111)

cm_gl = workflow.colors.cm_mapper(100, 103, 'winter')
cm_ss = workflow.colors.cm_mapper(1000,1017, 'autumn')

for i in subsurface_props.index:
    if i < 999:
        cl = cm_gl(i)
    else:
        cl = cm_ss(i)
    alpha = subsurface_props.loc[i]['van Genuchten alpha [Pa^-1]']
    n = subsurface_props.loc[i]['van Genuchten n [-]']
    sr = subsurface_props.loc[i]['residual saturation [-]']
    vg = plot_wrm.VanGenuchten(alpha, n, sr)
    plot_wrm.plot(vg, ax, cl)
    
# include wilting point limiters
wp1 = plot_wrm.WiltingPointLimiter(7400, 275000)
wp2 = plot_wrm.WiltingPointLimiter(6600, 255000)
wp3 = plot_wrm.WiltingPointLimiter(3500, 224000)
for wp in [wp1, wp2, wp3]:
    plot_wrm.plot(wp, ax, 'k')

    
plt.show()

# %% [markdown]
# ## Mesh extrusion
#
# Given the surface mesh and material IDs on both the surface and subsurface, we can extrude the surface mesh in the vertical to make a 3D mesh.
#
# The most difficult aspect of extrusion is creating meshes that:
# 1. aren't huge numbers of cells
# 2. aren't huge cell thicknesses, especially near the surface
# 3. follow implied interfaces, e.g. bottom of soil and bottom of geologic layer
#
# This is an iterative process that requires some care and some art.

# %%
# here we choose the bottom of the domain to be the maximum of the depth to bedrock.  
# This is really up to the user...
total_thickness = np.ceil(DTB.max())
print(f'total thickness: {total_thickness} m')

total_thickness = 41.0
# Out:
# total thickness: 40.0 m

# %%
# Generate a dz structure for the top 2m of soil
#
# here we try for 10 cells, starting at 5cm at the top and going to 50cm at the bottom of the 2m thick soil
dzs, res = workflow.mesh.optimize_dzs(0.05, 0.5, 2, 10)
print(dzs)
print(sum(dzs))
# Out:
# [0.0500016  0.05030145 0.06625834 0.1110568  0.22600204 0.49640501
#  0.49997989 0.49999487]
# 2.0

# %%
# this looks like it would work out, with rounder numbers:
dzs_soil = [0.05, 0.05, 0.05, 0.12, 0.23, 0.5, 0.5, 0.5]
print(sum(dzs_soil))
# Out:
# 2.0

# %%
# 41m total thickness, minus 2m soil thickness, leaves us with 39 meters to make up.
# optimize again...
dzs2, res2 = workflow.mesh.optimize_dzs(1, 10, 39, 8)
print(dzs2)
print(sum(dzs2))

# how about...
dzs_geo = [1.0, 3.0,] + 7*[5.0,]
print(dzs_geo)
print(sum(dzs_geo))
# Out:
# [ 1.43810942  2.49456441  5.06733261  9.99999356  9.99999999 10.        ]
# 39.0
# [1.0, 3.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0]
# 39.0

# %%
# layer extrusion
# -- data structures needed for extrusion
layer_types = []
layer_data = []
layer_ncells = []
layer_mat_ids = []

# -- soil layer --
depth = 0
for dz in dzs_soil:
    depth += 0.5 * dz
    layer_types.append('constant')
    layer_data.append(dz)
    layer_ncells.append(1)
    
    br_or_geo = np.where(depth < DTB, geo_color_new, 999)
    soil_or_br_or_geo = np.where(np.bitwise_and(soil_color_new > 0, depth < soil_thickness),
                                 soil_color_new,
                                 br_or_geo)
    
    layer_mat_ids.append(soil_or_br_or_geo)
    depth += 0.5 * dz
    
# -- geologic layer --
for dz in dzs_geo:
    depth += 0.5 * dz
    layer_types.append('constant')
    layer_data.append(dz)
    layer_ncells.append(1)
    layer_mat_ids.append(np.where(depth < DTB, geo_color_new, 999))
    depth += 0.5 * dz

# print the summary
workflow.mesh.Mesh3D.summarize_extrusion(layer_types, layer_data, 
                                            layer_ncells, layer_mat_ids)
# Out:
# 2021-07-23 10:14:42,238 - root - INFO: Cell summary:
# 2021-07-23 10:14:42,238 - root - INFO: ------------------------------------------------------------
# 2021-07-23 10:14:42,239 - root - INFO: l_id	| c_id	|mat_id	| dz		| z_top
# 2021-07-23 10:14:42,239 - root - INFO: ------------------------------------------------------------
# 2021-07-23 10:14:42,240 - root - INFO:  00 	| 00 	| 1001 	|   0.050000 	|   0.000000
# 2021-07-23 10:14:42,240 - root - INFO:  01 	| 01 	| 1001 	|   0.050000 	|   0.050000
# 2021-07-23 10:14:42,240 - root - INFO:  02 	| 02 	| 1001 	|   0.050000 	|   0.100000
# 2021-07-23 10:14:42,241 - root - INFO:  03 	| 03 	| 1001 	|   0.120000 	|   0.150000
# 2021-07-23 10:14:42,241 - root - INFO:  04 	| 04 	| 1001 	|   0.230000 	|   0.270000
# 2021-07-23 10:14:42,242 - root - INFO:  05 	| 05 	| 1001 	|   0.500000 	|   0.500000
# 2021-07-23 10:14:42,242 - root - INFO:  06 	| 06 	| 1001 	|   0.500000 	|   1.000000
# 2021-07-23 10:14:42,242 - root - INFO:  07 	| 07 	|  103 	|   0.500000 	|   1.500000
# 2021-07-23 10:14:42,243 - root - INFO:  08 	| 08 	|  103 	|   1.000000 	|   2.000000
# 2021-07-23 10:14:42,243 - root - INFO:  09 	| 09 	|  103 	|   3.000000 	|   3.000000
# 2021-07-23 10:14:42,244 - root - INFO:  10 	| 10 	|  103 	|   5.000000 	|   6.000000
# 2021-07-23 10:14:42,244 - root - INFO:  11 	| 11 	|  103 	|   5.000000 	|  11.000000
# 2021-07-23 10:14:42,245 - root - INFO:  12 	| 12 	|  103 	|   5.000000 	|  16.000000
# 2021-07-23 10:14:42,245 - root - INFO:  13 	| 13 	|  103 	|   5.000000 	|  21.000000
# 2021-07-23 10:14:42,246 - root - INFO:  14 	| 14 	|  103 	|   5.000000 	|  26.000000
# 2021-07-23 10:14:42,246 - root - INFO:  15 	| 15 	|  103 	|   5.000000 	|  31.000000
# 2021-07-23 10:14:42,246 - root - INFO:  16 	| 16 	|  999 	|   5.000000 	|  36.000000

# %%
# extrude
m3 = workflow.mesh.Mesh3D.extruded_Mesh2D(m2, layer_types, layer_data, 
                                             layer_ncells, layer_mat_ids)

# %%
# add back on land cover side sets
surf_ss = m3.side_sets[1]

for index, nlcd_name in zip(nlcd_indices, nlcd_labels):
    where = np.where(nlcd_color_new == index)[0]
    print(index, nlcd_name, len(where))
    ss = workflow.mesh.SideSet(nlcd_name, int(index), 
                            [surf_ss.elem_list[w] for w in where],
                            [surf_ss.side_list[w] for w in where])        
    m3.side_sets.append(ss)
# Out:
# 99 Other 286
# 41 Deciduous Forest 517
# 42 Evergreen Forest 2757
# 52 Shrub/Scrub 888

# %%
# save to disk
outputs['mesh_filename'] = f'../data-processed/{name}.exo'
try:
    os.remove(outputs['mesh_filename'])
except FileNotFoundError:
    pass
m3.write_exodus(outputs['mesh_filename'])
# Out:
# You are using exodus.py v 1.20.7 (seacas-py3), a python wrapper of some of the exodus library.
#
# Copyright (c) 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021 National Technology &
# Engineering Solutions of Sandia, LLC (NTESS).  Under the terms of
# Contract DE-NA0003525 with NTESS, the U.S. Government retains certain
# rights in this software.
#
# Opening exodus file: ../data-processed/CoalCreek.exo
# Closing exodus file: ../data-processed/CoalCreek.exo

# %% [markdown]
# ## Collect the DayMet raster covering this area
#
# Note that here we need two files -- the actual data and the typical year data.
#
# The first cell downloads the raw data and generates the actual data file used by ATS, the second cell averages days, smooths the data, and writes a typical year.

# %%
start = "1-1980"
end = "365-2020"
bounds = watershed.exterior().bounds

outputs['daymet_filename'] = f'../data-processed/{name}_DayMet_1980_2020.h5'

dat, x, y = workflow.daymet.collectDaymet(bounds, crs, start, end)
ats = workflow.daymet.daymetToATS(dat)
attrs = workflow.daymet.getAttrs(bounds, start, end)
workflow.daymet.writeHDF5(ats, x, y, attrs, outputs['daymet_filename'])
# Out:
# 2021-07-23 10:14:44,276 - root - INFO: downloading variables: ['tmin', 'tmax', 'prcp', 'srad', 'vp', 'swe', 'dayl']
# 2021-07-23 10:14:44,310 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,311 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1980_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,360 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,362 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1980_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,398 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,400 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1980_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,435 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,436 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1980_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,473 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,474 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1980_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,510 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,512 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1980_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,548 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,549 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1980_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,585 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,587 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1981_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,622 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,623 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1981_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,659 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,661 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1981_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,697 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,698 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1981_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,736 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,737 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1981_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,775 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,776 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1981_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,812 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,813 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1981_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,848 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,849 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1982_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,886 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,887 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1982_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,924 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,925 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1982_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,962 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,963 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1982_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:44,998 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:44,999 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1982_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,034 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,035 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1982_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,071 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,073 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1982_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,107 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,108 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1983_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,144 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,145 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1983_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,181 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,182 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1983_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,219 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,220 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1983_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,254 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,255 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1983_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,292 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,293 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1983_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,330 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,331 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1983_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,367 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,368 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1984_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,403 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,405 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1984_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,442 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,443 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1984_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,479 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,480 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1984_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,516 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,518 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1984_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,553 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,554 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1984_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,589 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,590 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1984_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,631 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,632 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1985_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,671 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,672 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1985_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,708 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,709 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1985_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,745 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,747 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1985_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,783 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,784 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1985_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,823 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,825 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1985_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,861 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,861 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1985_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,898 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,899 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1986_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,935 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,936 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1986_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:45,972 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:45,973 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1986_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,009 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,010 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1986_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,047 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,048 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1986_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,085 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,086 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1986_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,123 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,124 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1986_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,159 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,160 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1987_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,196 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,197 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1987_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,234 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,235 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1987_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,273 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,274 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1987_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,310 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,311 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1987_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,347 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,348 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1987_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,382 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,383 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1987_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,419 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,420 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1988_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,456 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,457 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1988_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,493 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,494 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1988_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,529 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,530 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1988_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,565 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,566 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1988_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,601 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,602 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1988_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,642 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,643 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1988_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,678 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,679 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1989_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,715 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,716 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1989_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,752 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,753 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1989_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,789 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,790 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1989_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,826 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,827 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1989_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,862 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,863 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1989_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,898 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,899 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1989_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,934 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,936 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1990_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:46,972 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:46,973 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1990_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,009 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,010 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1990_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,045 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,046 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1990_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,081 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,082 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1990_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,119 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,120 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1990_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,156 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,157 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1990_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,194 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,195 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1991_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,232 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,232 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1991_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,269 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,270 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1991_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,307 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,308 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1991_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,343 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,345 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1991_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,380 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,382 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1991_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,417 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,418 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1991_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,455 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,456 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1992_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,492 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,493 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1992_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,528 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,529 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1992_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,566 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,567 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1992_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,602 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,603 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1992_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,641 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,643 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1992_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,679 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,680 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1992_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,715 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,716 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1993_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,750 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,751 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1993_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,786 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,787 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1993_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,824 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,825 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1993_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,860 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,861 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1993_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,896 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,897 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1993_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,932 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,933 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1993_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:47,969 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:47,970 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1994_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,004 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,005 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1994_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,040 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,041 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1994_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,077 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,079 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1994_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,114 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,115 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1994_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,150 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,152 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1994_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,188 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,189 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1994_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,224 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,225 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1995_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,260 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,261 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1995_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,299 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,300 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1995_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,336 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,337 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1995_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,374 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,376 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1995_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,411 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,412 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1995_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,449 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,450 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1995_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,487 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,488 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1996_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,525 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,527 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1996_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,563 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,564 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1996_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,600 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,601 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1996_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,638 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,640 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1996_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,676 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,677 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1996_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,712 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,714 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1996_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,749 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,750 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1997_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,786 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,787 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1997_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,824 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,825 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1997_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,860 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,861 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1997_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,897 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,898 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1997_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,933 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,934 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1997_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:48,971 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:48,972 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1997_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,007 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,008 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1998_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,042 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,044 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1998_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,080 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,081 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1998_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,117 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,119 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1998_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,153 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,154 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1998_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,190 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,191 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1998_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,227 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,228 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1998_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,264 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,266 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_1999_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,300 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,301 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_1999_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,338 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,339 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_1999_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,375 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,377 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_1999_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,413 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,414 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_1999_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,449 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,450 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_1999_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,487 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,488 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_1999_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,523 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,524 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_2000_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,559 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,560 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_2000_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,596 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,597 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_2000_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,634 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,635 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_2000_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,671 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,672 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_2000_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,707 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,708 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_2000_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,744 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,745 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_2000_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,782 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,783 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_2001_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,820 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,821 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_2001_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,855 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,856 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_2001_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,893 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,894 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_2001_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,931 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,932 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_2001_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:49,968 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:49,969 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_2001_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:50,004 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:50,006 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_2001_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:50,041 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:50,043 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_2002_38.9099x-107.1193_38.8162x-106.9628.nc
# ...
# 2021-07-23 10:14:53,051 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_2013_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,086 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,087 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_2013_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,122 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,123 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_2014_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,160 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,161 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_2014_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,197 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,199 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_2014_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,233 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,234 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_2014_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,269 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,271 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_2014_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,306 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,308 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_2014_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,344 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,345 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_2014_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,381 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,382 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_2015_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,416 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,417 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_2015_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,452 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,454 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_2015_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,490 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,491 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_2015_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,531 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,532 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_2015_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,566 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,567 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_2015_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,602 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,603 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_2015_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,637 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,638 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_2016_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,674 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,675 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_2016_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,712 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,713 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_2016_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,747 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,748 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_2016_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,783 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,784 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_2016_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,819 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,821 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_2016_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,856 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,857 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_2016_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,892 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,893 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_2017_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,930 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,931 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_2017_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:53,967 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:53,968 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_2017_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,002 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,003 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_2017_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,039 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,040 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_2017_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,076 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,077 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_2017_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,113 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,114 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_2017_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,148 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,149 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_2018_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,183 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,184 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_2018_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,219 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,221 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_2018_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,255 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,256 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_2018_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,291 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,292 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_2018_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,327 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,328 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_2018_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,363 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,364 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_2018_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,399 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,400 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_2019_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,437 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,438 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_2019_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,476 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,477 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_2019_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,513 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,515 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_2019_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,553 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,554 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_2019_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,591 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,592 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_2019_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,627 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,628 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_2019_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,664 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,666 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmin_2020_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,701 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,702 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_tmax_2020_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,739 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,740 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_prcp_2020_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,775 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,776 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_srad_2020_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,811 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,812 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_vp_2020_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,849 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,850 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_swe_2020_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,885 - root - INFO: Collecting DayMet file to tile bounds: [-107.11930000000001, 38.8162, -106.9628, 38.9099]
# 2021-07-23 10:14:54,886 - root - INFO:   Using existing: /Users/uec/code/watershed_workflow/data-library/meteorology/daymet/daymet_dayl_2020_38.9099x-107.1193_38.8162x-106.9628.nc
# 2021-07-23 10:14:54,891 - root - INFO: seconds to write: 10.615106105804443 s
# 2021-07-23 10:14:54,891 - root - INFO: input dat shape: (14965, 12, 14)
# 2021-07-23 10:14:54,892 - root - INFO: Converting to ATS met input
# 2021-07-23 10:14:55,009 - root - INFO: Writing HDF5 file: ../data-processed/CoalCreek_DayMet_1980_2020.h5

# %%
outputs['daymet_spinup_filename'] = f'../data-processed/{name}_DayMet_typical_1980_2020.h5'

ats_typ = workflow.daymet.daymetToATS(dat, smooth=True, smooth_filter=True, nyears=40)
workflow.daymet.writeHDF5(ats_typ, x, y, attrs, outputs['daymet_spinup_filename'])
# Out:
# 2021-07-23 10:15:14,737 - root - INFO: input dat shape: (14965, 12, 14)
# 2021-07-23 10:15:14,738 - root - INFO: Converting to ATS met input
# 2021-07-23 10:15:14,738 - root - INFO: averaging daymet by taking the average for each day across the actual years.
# 2021-07-23 10:15:14,740 - root - INFO: smoothing tmin using savgol filter, window = 61 d, poly order = 2
# 2021-07-23 10:15:14,748 - root - INFO: smoothing tmax using savgol filter, window = 61 d, poly order = 2
# 2021-07-23 10:15:14,754 - root - INFO: smoothing prcp using savgol filter, window = 61 d, poly order = 2
# 2021-07-23 10:15:14,760 - root - INFO: smoothing srad using savgol filter, window = 61 d, poly order = 2
# 2021-07-23 10:15:14,773 - root - INFO: smoothing vp using savgol filter, window = 61 d, poly order = 2
# 2021-07-23 10:15:14,786 - root - INFO: smoothing swe using savgol filter, window = 61 d, poly order = 2
# 2021-07-23 10:15:14,798 - root - INFO: smoothing dayl using savgol filter, window = 61 d, poly order = 2
# 2021-07-23 10:15:14,809 - root - INFO: shape of smoothed dat is (14600, 12, 14)
# 2021-07-23 10:15:14,932 - root - INFO: Writing HDF5 file: ../data-processed/CoalCreek_DayMet_typical_1980_2020.h5

# %% [markdown]
# ## Generate files for Leaf Area Index
#
# In addition to meteorological forcing data, we need land cover leaf area index data.  Typically this can be smoother than the DayMet, and our default source for this, MODIS, is not currently automated.  Therefore this assumes you have already acquired the raw MODIS data (note -- get Pin to add his scripts for this!)
#
# MODIS is available from 2002 to present -- we generate a typical year and can use that for all years, though probably we should do something smarter if possible.

# %%
def plot(df, form, axs):
    cm = workflow.colors.enumerated_colors(3)
    i = 0
    for k in df.keys():
        if not k.startswith('time'):
            axs[i].plot(df['time [d]'], df[k], form, color=cm[i])
            axs[i].set_ylabel(k)
            i += 1

# %%
# load the raw MODIS data and covert it to pandas
raw_modis_filename = f'../data-raw/{name}_MODIS_LAI-072002_122019.h5'

d = h5py.File(raw_modis_filename,'r')
df = pandas.DataFrame()
for k in d.keys():
    df[k] = d[k][:]

df['time [d]'] = df['time [s]']/86400

# %%
# interpolate this time series into a daily time series
ts = np.arange(8214, 14600, 1)

df_interp = pandas.DataFrame()
df_interp['time [d]'] = ts

for k in df.keys():
    if k != 'time [s]':
        f = scipy.interpolate.interp1d(df['time [d]'][:], df[k][:])
        df_interp[k] = f(ts)

df = df_interp

# %%
# smooth the data
df_smooth = pandas.DataFrame()
df_smooth['time [d]'] = df['time [d]']
for k in df.keys():
    if k != 'time [d]':
        df_smooth[k] = scipy.signal.savgol_filter(df[k], 101, 3)

        
# plot comparison
fig = plt.figure()
axs = fig.subplots(3,1)
#plot(df, '-', axs)
plot(df_smooth, '-', axs)
plt.show()

# %%
# add time back and write to disk
outputs['modis_filename'] = f'../data-processed/{name}_MODIS_LAI_smoothed_2002_2020.h5'

df_smooth['time [s]'] = df_smooth['time [d]']*86400
with h5py.File(outputs['modis_filename'],'w') as fid:
    for k in df_smooth:
        fid.create_dataset(k, data=df_smooth[k][:])

# %%
df = df_smooth

# split into n_years dataframes, one per year
df_yr = []
for year in range(23, 39):
    yr = df.loc[df_interp['time [d]'] >= year*365]
    df_yr.append(yr.loc[yr['time [d]'] < (year+1)*365])

# average across the years
df_avg = pandas.DataFrame()
for yr in df_yr:
    for k in yr.keys():
        if not k.startswith('time'):
            if k in df_avg:
                df_avg[k] = df_avg[k].array + yr[k].array
            else:
                df_avg[k] = yr[k].copy()

for k in df_avg.keys():
    df_avg[k] = df_avg[k][:] / len(df_yr)

df_avg['time [d]'] = df['time [d]']

# %%
# replicate 40 times to make 40 years (remem)
# tile all data to repeat n_year times
df_rep = pandas.DataFrame()
for key in df_avg:
    if not key.startswith('time'):
        df_rep[key] = np.tile(df_avg[key].array, 40)
        assert(len(df_rep) == 40*365)
    
# time is simply daily data
df_rep['time [s]'] = 86400. * np.arange(0., 40 * 365., 1.)
df_rep['time [d]'] = np.arange(0., 40 * 365., 1.)

# %%
# plot this and make sure it looks right
fig = plt.figure()
axs = fig.subplots(3,1)
plot(df_rep, '-', axs)
plt.show()

# %%
# write to disk
outputs['modis_typical_filename'] = f'../data-processed/{name}_MODIS_LAI_typical_1980_2020.h5'

with h5py.File(outputs['modis_typical_filename'],'w') as fid:
    for k in df_rep:
        fid.create_dataset(k, data=df_rep[k][:])

# %% [markdown]
# ## Write ATS input files
#
# We now generate three input files -- two for spinup (steadystate solution and cyclic steadystate solution) and one for transient runs.
#
# Steadystate has its own physics, but cyclic steadystate and transient share a common set of physics.  Each have their own met data strategy.
#
# The first step is to generate the sections of xml that will replace parts of the template files.  This is done prior to loading any templates to make clear that these are totally generated from scratch using the ats_input_spec tool.
#
# Note that throughout, we will assume an additional level of folder nesting, e.g. runs will be completed in '../spinup-CoalCreek/run0', meaning that we have to append an extra '../' to the start of all filenames.  This makes it easier to deal with mistakes, continued runs, etc.

# %%
# get an ATS "main" input spec list
main_list = ats_input_spec.public.get_main()

# %%
# add the subsurface and surface domains
#
# Note this also adds a "computational domain" region to the region list, and a vis spec 
# for "domain"
mesh_filename = os.path.join('..', outputs['mesh_filename'])

ats_input_spec.public.add_domain(main_list, 
                                 domain_name='domain', 
                                 dimension=3, 
                                 mesh_type='read mesh file', 
                                 mesh_args={'file':mesh_filename})
main_list['mesh']['domain']['build columns from set'] = 'surface'

# Note this also adds a "surface domain" region to the region list and a vis spec for 
# "surface"
ats_input_spec.public.add_domain(main_list,
                                domain_name='surface',
                                dimension=2,
                                mesh_type='surface',
                                mesh_args={'surface sideset name':'surface'})

# Add the snow and canopy domains, which are aliases to the surface
ats_input_spec.public.add_domain(main_list,
                                domain_name='snow',
                                dimension=2,
                                mesh_type='aliased',
                                mesh_args={'target':'surface'})
ats_input_spec.public.add_domain(main_list,
                                domain_name='canopy',
                                dimension=2,
                                mesh_type='aliased',
                                mesh_args={'target':'surface'})

# add the "surface boundary" list
ats_input_spec.public.add_region(main_list,
                                region_name='surface boundary',
                                region_type='boundary',
                                region_args={'entity': 'FACE'})

def add_labeled_set(ls_name, label, entity_kind):
    """Helper function to add labeled sets to the main list"""
    ats_input_spec.public.add_region(main_list,
                                    region_name=ls_name,
                                    region_type='labeled set',
                                    region_args={'label' : str(label), 
                                                 'file' : mesh_filename,
                                                 'format' : 'Exodus II',
                                                 'entity' : entity_kind})

# add the bottom and surface sets
add_labeled_set('bottom_face', 1, 'FACE')
add_labeled_set('surface', 2, 'FACE')

# add the NLCD labeled sets
for index, nlcd_name in zip(nlcd_indices, nlcd_labels):
    add_labeled_set(nlcd_name, index, 'FACE')

# add soil sets: note we need a way to name the set, so we use, e.g. SSURGO-MUKEY.
def soil_set_name(ats_id):
    if ats_id == 999:
        return 'bedrock'
    source = subsurface_props.loc[ats_id]['source']
    native_id = subsurface_props.loc[ats_id]['native_index']
    if type(native_id) in [tuple,list]:
        native_id = native_id[0]
    return f"{source}-{native_id}"

for ats_id in subsurface_props.index:
    set_name = soil_set_name(ats_id)
    add_labeled_set(set_name, ats_id, 'CELL')

print(main_list)
# Out:
# mesh [mesh-typed-spec-list] : [complete]
#   domain [TypedCollection] : [complete]
#     mesh type [string] : read mesh file
#     read mesh file parameters [unknown derived parameter] : [complete]
#       file [string] : ../../data-processed/CoalCreek.exo
#     verify mesh [bool] : false
#     deformable mesh [bool] : false
#     build columns from set [string] : surface
#     partitioner [string] : zoltan_rcb
#   surface [TypedCollection] : [complete]
#     mesh type [string] : surface
#     surface parameters [unknown derived parameter] : [complete]
#       surface sideset name [string] : surface
#       verify mesh [bool] : false
#       export mesh to file [string] : [optional]
#     verify mesh [bool] : false
#     deformable mesh [bool] : false
#     build columns from set [string] : [optional]
#     partitioner [string] : zoltan_rcb
#   snow [TypedCollection] : [complete]
#     mesh type [string] : aliased
#     aliased parameters [unknown derived parameter] : [complete]
#       target [string] : surface
#     verify mesh [bool] : false
#     deformable mesh [bool] : false
#     build columns from set [string] : [optional]
#     partitioner [string] : zoltan_rcb
#   canopy [TypedCollection] : [complete]
#     mesh type [string] : aliased
#     aliased parameters [unknown derived parameter] : [complete]
#       target [string] : surface
#     verify mesh [bool] : false
#     deformable mesh [bool] : false
#     build columns from set [string] : [optional]
#     partitioner [string] : zoltan_rcb
# regions [region-typedsublist-spec-list] : [complete]
#   computational domain [TypedCollection] : [complete]
#     region: all [False] : [complete]
#       empty [bool] : true
#   surface domain [TypedCollection] : [complete]
#     region: all [False] : [complete]
#       empty [bool] : true
#   snow domain [TypedCollection] : [complete]
#     region: all [False] : [complete]
#       empty [bool] : true
#   canopy domain [TypedCollection] : [complete]
#     region: all [False] : [complete]
#       empty [bool] : true
#   surface boundary [TypedCollection] : [complete]
#     region: boundary [False] : [complete]
#       entity [string] : FACE
#   bottom_face [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : FACE
#   surface [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 2
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : FACE
#   Other [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 99
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : FACE
#   Deciduous Forest [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 41
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : FACE
#   Evergreen Forest [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 42
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : FACE
#   Shrub/Scrub [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 52
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : FACE
#   GLHYMPS-715639 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 100
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   GLHYMPS-715779 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 101
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   GLHYMPS-715766 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 102
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   GLHYMPS-730801 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 103
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-498185 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1000
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-498205 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1001
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-498206 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1002
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-498208 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1003
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-498231 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1004
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509477 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1005
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509479 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1006
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509481 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1007
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509482 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1008
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509513 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1009
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509514 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1010
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509529 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1011
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509532 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1012
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509548 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1013
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509559 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1014
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509561 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1015
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509733 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1016
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   NRCS-509794 [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 1017
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
#   bedrock [TypedCollection] : [complete]
#     region: labeled set [False] : [complete]
#       label [string] : 999
#       file [string] : ../../data-processed/CoalCreek.exo
#       format [string] : Exodus II
#       entity [string] : CELL
# cycle driver [coordinator-spec] : [incomplete]
#   ONE OF:
#     end time [double] : None
#     end time units [string] : "s"
#   OR:
#     end cycle [int] : [optional]
#   start time [double] : 0.00000000
#   start time units [string] : "s"
#   subcycled timestep [bool] : false
#   restart from checkpoint file [string] : [optional]
#   wallclock duration [hrs] [double] : [optional]
#   required times [io-event-spec] : [optional]
#     cycles start period stop [Array(int)] : [optional]
#     cycles start period stop 0 [Array(int)] : [optional]
#     cycles [Array(int)] : [optional]
#     times start period stop [Array(double)] : [optional]
#     times start period stop units [string] : s
#     times start period stop 0 [Array(double)] : [optional]
#     times start period stop 0 units [string] : s
#     times [Array(double)] : [optional]
#     times units [string] : s
#   PK tree [pk-typed-spec-list] : [incomplete]
#
# visualization [visualization-spec-list] : [complete]
#   domain [TypedCollection] : [optional]
#     file name base [string] : visdump_DOMAIN_data
#     dynamic mesh [bool] : false
#     time unit [string] : s
#     cycles start period stop [Array(int)] : [optional]
#     cycles start period stop 0 [Array(int)] : [optional]
#     cycles [Array(int)] : [optional]
#     times start period stop [Array(double)] : [optional]
#     times start period stop units [string] : s
#     times start period stop 0 [Array(double)] : [optional]
#     times start period stop 0 units [string] : s
#     times [Array(double)] : [optional]
#     times units [string] : s
#   surface [TypedCollection] : [optional]
#     file name base [string] : visdump_DOMAIN_data
#     dynamic mesh [bool] : false
#     time unit [string] : s
#     cycles start period stop [Array(int)] : [optional]
#     cycles start period stop 0 [Array(int)] : [optional]
#     cycles [Array(int)] : [optional]
#     times start period stop [Array(double)] : [optional]
#     times start period stop units [string] : s
#     times start period stop 0 [Array(double)] : [optional]
#     times start period stop 0 units [string] : s
#     times [Array(double)] : [optional]
#     times units [string] : s
#   snow [TypedCollection] : [optional]
#     file name base [string] : visdump_DOMAIN_data
#     dynamic mesh [bool] : false
#     time unit [string] : s
#     cycles start period stop [Array(int)] : [optional]
#     cycles start period stop 0 [Array(int)] : [optional]
#     cycles [Array(int)] : [optional]
#     times start period stop [Array(double)] : [optional]
#     times start period stop units [string] : s
#     times start period stop 0 [Array(double)] : [optional]
#     times start period stop 0 units [string] : s
#     times [Array(double)] : [optional]
#     times units [string] : s
#   canopy [TypedCollection] : [optional]
#     file name base [string] : visdump_DOMAIN_data
#     dynamic mesh [bool] : false
#     time unit [string] : s
#     cycles start period stop [Array(int)] : [optional]
#     cycles start period stop 0 [Array(int)] : [optional]
#     cycles [Array(int)] : [optional]
#     times start period stop [Array(double)] : [optional]
#     times start period stop units [string] : s
#     times start period stop 0 [Array(double)] : [optional]
#     times start period stop 0 units [string] : s
#     times [Array(double)] : [optional]
#     times units [string] : s
# observations [observation-spec-list] : [incomplete]
#
# checkpoint [checkpoint-spec] : [optional]
#   file name base [string] : "checkpoint"
#   file name digits [int] : <class 'int'>
#   single file checkpoint [bool] : true
#   cycles start period stop [Array(int)] : [optional]
#   cycles start period stop 0 [Array(int)] : [optional]
#   cycles [Array(int)] : [optional]
#   times start period stop [Array(double)] : [optional]
#   times start period stop units [string] : s
#   times start period stop 0 [Array(double)] : [optional]
#   times start period stop 0 units [string] : s
#   times [Array(double)] : [optional]
#   times units [string] : s
# PKs [pk-typed-spec-list] : [incomplete]
#
# state [state-spec] : [incomplete]
#   field evaluators [field-evaluator-typedinline-spec-list] : [incomplete]
#
#   initial conditions [list] : [incomplete]

# %%
# next write a land-cover section for each NLCD type
land_cover_list = ats_input_spec.public.known_specs['land-cover-spec-list']
main_list['state']['initial conditions']['land cover types'] = land_cover_list

def add_land_cover_default(main, lc_name):
    """Adds a default land-cover type to the spec."""
    lc = main['state']['initial conditions']['land cover types'].append_empty(lc_name)
    
    # set some basic defaults
    lc['Priestley-Taylor alpha of snow [-]'] = 1.26
    lc['Priestley-Taylor alpha of bare ground [-]'] = 1.26
    lc['Priestley-Taylor alpha of canopy [-]'] = 1.26
    lc['Priestley-Taylor alpha of transpiration [-]'] = 1.26

    lc['albedo of bare ground [-]'] = 0.4
    lc['emissivity of bare ground [-]'] = 0.98
    lc['albedo of canopy [-]'] = 0.11
    lc['emissivity of canopy [-]'] = 0.95
    
    lc["Beer's law extinction coefficient, shortwave [-]"] = 0.6
    lc["Beer's law extinction coefficient, longwave [-]"] = 5
    
    lc["snow transition depth [m]"] = 0.02
    lc["dessicated zone thickness [m]"] = 0.1
    lc["Clapp and Hornberger b [-]"] = 1
    
    # defaults for grass/no vei
    lc['rooting depth max [m]'] = 5.
    lc['rooting profile alpha [-]'] = 11.0
    lc['rooting profile beta [-]'] = 2.0
    
    
    # Note, the mafic potential values are likely pretty bad for the types of van Genuchten 
    # curves we are using (https://www.sciencedirect.com/science/article/pii/S0168192314000483).
    # Likely they need to be modified.  Note that these values are in [mm] from CLM TN 4.5 table 8.1, so the 
    # factor of 10 converts to [Pa].
    #
    # instead of using a factor of 10, we use a factor of 1 for closed and .1 for open to make this more 
    # physically viable for our VG models
    lc['mafic potential at fully closed stomata [Pa]'] = 275000.
    lc['mafic potential at fully open stomata [Pa]'] = 74000. * .1
    
    # by default we let the LAI take care of this rather than turn off deciduous 
    # transpiration manually the way that PRMS does it. 
    lc['leaf on time [doy]'] = -1
    lc['leaf off time [doy]'] = -1
    return lc

# add default lists for all types
for index, nlcd_name in zip(nlcd_indices, nlcd_labels):
    lc = add_land_cover_default(main_list, nlcd_name)

# update some defaults
# ['Other', 'Deciduous Forest', 'Evergreen Forest', 'Shrub/Scrub']
# note, these are from the CLM Technical Note v4.5
#
# Rooting depth curves from CLM TN 4.5 table 8.3
#
# Note, the mafic potential values are likely pretty bad for the types of van Genuchten 
# curves we are using (ETC -- add paper citation about this topic).  Likely they need
# to be modified.  Note that these values are in [mm] from CLM TN 4.5 table 8.1, so the 
# factor of 10 converts to [Pa]
#
# Note, albedo of canopy taken from CLM TN 4.5 table 3.1
land_cover_list['Evergreen Forest']['rooting profile alpha [-]'] = 7.0
land_cover_list['Evergreen Forest']['rooting profile beta [-]'] = 2.0
land_cover_list['Evergreen Forest']['rooting depth max [m]'] = 10.0
land_cover_list['Evergreen Forest']['mafic potential at fully closed stomata [Pa]'] = 255000
land_cover_list['Evergreen Forest']['mafic potential at fully open stomata [Pa]'] = 66000 * .1
land_cover_list['Evergreen Forest']['albedo of canopy [-]'] = 0.07

land_cover_list['Deciduous Forest']['rooting profile alpha [-]'] = 6.0
land_cover_list['Deciduous Forest']['rooting profile beta [-]'] = 2.0
land_cover_list['Deciduous Forest']['rooting depth max [m]'] = 10.0
land_cover_list['Deciduous Forest']['mafic potential at fully closed stomata [Pa]'] = 224000
land_cover_list['Deciduous Forest']['mafic potential at fully open stomata [Pa]'] = 35000 * .10
land_cover_list['Deciduous Forest']['albedo of canopy [-]'] = 0.1

print(land_cover_list)
# Out:
# Other [TypedCollection] : [complete]
#   rooting depth max [m] [double] : 5.00000000
#   rooting profile alpha [-] [double] : 11.00000000
#   rooting profile beta [-] [double] : 2.00000000
#   mafic potential at fully closed stomata [Pa] [double] : 275000.00000000
#   mafic potential at fully open stomata [Pa] [double] : 7400.00000000
#   leaf on time [doy] [double] : -1.00000000
#   leaf off time [doy] [double] : -1.00000000
#   Priestley-Taylor alpha of snow [-] [double] : 1.26000000
#   Priestley-Taylor alpha of bare ground [-] [double] : 1.26000000
#   Priestley-Taylor alpha of canopy [-] [double] : 1.26000000
#   Priestley-Taylor alpha of transpiration [-] [double] : 1.26000000
#   interception coefficient [-] [double] : nan
#   albedo of bare ground [-] [double] : 0.40000000
#   emissivity of bare ground [-] [double] : 0.98000000
#   albedo of canopy [-] [double] : 0.11000000
#   emissivity of canopy [-] [double] : 0.95000000
#   Beer's law extinction coefficient, shortwave [-] [double] : 0.60000000
#   Beer's law extinction coefficient, longwave [-] [double] : 5.00000000
#   snow transition depth [m] [double] : 0.02000000
#   water transition depth [m] [double] : nan
#   dessicated zone thickness [m] [double] : 0.10000000
#   Clapp and Hornberger b [-] [double] : 1.00000000
#   roughness length of bare ground [m] [double] : nan
#   roughness length of snow [m] [double] : nan
# Deciduous Forest [TypedCollection] : [complete]
#   rooting depth max [m] [double] : 10.00000000
#   rooting profile alpha [-] [double] : 6.00000000
#   rooting profile beta [-] [double] : 2.00000000
#   mafic potential at fully closed stomata [Pa] [double] : 224000.00000000
#   mafic potential at fully open stomata [Pa] [double] : 3500.00000000
#   leaf on time [doy] [double] : -1.00000000
#   leaf off time [doy] [double] : -1.00000000
#   Priestley-Taylor alpha of snow [-] [double] : 1.26000000
#   Priestley-Taylor alpha of bare ground [-] [double] : 1.26000000
#   Priestley-Taylor alpha of canopy [-] [double] : 1.26000000
#   Priestley-Taylor alpha of transpiration [-] [double] : 1.26000000
#   interception coefficient [-] [double] : nan
#   albedo of bare ground [-] [double] : 0.40000000
#   emissivity of bare ground [-] [double] : 0.98000000
#   albedo of canopy [-] [double] : 0.10000000
#   emissivity of canopy [-] [double] : 0.95000000
#   Beer's law extinction coefficient, shortwave [-] [double] : 0.60000000
#   Beer's law extinction coefficient, longwave [-] [double] : 5.00000000
#   snow transition depth [m] [double] : 0.02000000
#   water transition depth [m] [double] : nan
#   dessicated zone thickness [m] [double] : 0.10000000
#   Clapp and Hornberger b [-] [double] : 1.00000000
#   roughness length of bare ground [m] [double] : nan
#   roughness length of snow [m] [double] : nan
# Evergreen Forest [TypedCollection] : [complete]
#   rooting depth max [m] [double] : 10.00000000
#   rooting profile alpha [-] [double] : 7.00000000
#   rooting profile beta [-] [double] : 2.00000000
#   mafic potential at fully closed stomata [Pa] [double] : 255000.00000000
#   mafic potential at fully open stomata [Pa] [double] : 6600.00000000
#   leaf on time [doy] [double] : -1.00000000
#   leaf off time [doy] [double] : -1.00000000
#   Priestley-Taylor alpha of snow [-] [double] : 1.26000000
#   Priestley-Taylor alpha of bare ground [-] [double] : 1.26000000
#   Priestley-Taylor alpha of canopy [-] [double] : 1.26000000
#   Priestley-Taylor alpha of transpiration [-] [double] : 1.26000000
#   interception coefficient [-] [double] : nan
#   albedo of bare ground [-] [double] : 0.40000000
#   emissivity of bare ground [-] [double] : 0.98000000
#   albedo of canopy [-] [double] : 0.07000000
#   emissivity of canopy [-] [double] : 0.95000000
#   Beer's law extinction coefficient, shortwave [-] [double] : 0.60000000
#   Beer's law extinction coefficient, longwave [-] [double] : 5.00000000
#   snow transition depth [m] [double] : 0.02000000
#   water transition depth [m] [double] : nan
#   dessicated zone thickness [m] [double] : 0.10000000
#   Clapp and Hornberger b [-] [double] : 1.00000000
#   roughness length of bare ground [m] [double] : nan
#   roughness length of snow [m] [double] : nan
# Shrub/Scrub [TypedCollection] : [complete]
#   rooting depth max [m] [double] : 5.00000000
#   rooting profile alpha [-] [double] : 11.00000000
#   rooting profile beta [-] [double] : 2.00000000
#   mafic potential at fully closed stomata [Pa] [double] : 275000.00000000
#   mafic potential at fully open stomata [Pa] [double] : 7400.00000000
#   leaf on time [doy] [double] : -1.00000000
#   leaf off time [doy] [double] : -1.00000000
#   Priestley-Taylor alpha of snow [-] [double] : 1.26000000
#   Priestley-Taylor alpha of bare ground [-] [double] : 1.26000000
#   Priestley-Taylor alpha of canopy [-] [double] : 1.26000000
#   Priestley-Taylor alpha of transpiration [-] [double] : 1.26000000
#   interception coefficient [-] [double] : nan
#   albedo of bare ground [-] [double] : 0.40000000
#   emissivity of bare ground [-] [double] : 0.98000000
#   albedo of canopy [-] [double] : 0.11000000
#   emissivity of canopy [-] [double] : 0.95000000
#   Beer's law extinction coefficient, shortwave [-] [double] : 0.60000000
#   Beer's law extinction coefficient, longwave [-] [double] : 5.00000000
#   snow transition depth [m] [double] : 0.02000000
#   water transition depth [m] [double] : nan
#   dessicated zone thickness [m] [double] : 0.10000000
#   Clapp and Hornberger b [-] [double] : 1.00000000
#   roughness length of bare ground [m] [double] : nan
#   roughness length of snow [m] [double] : nan

# %%
# finally, we write soil property specs for porosity, permeability, and WRMs
poro_eval = main_list['state']['field evaluators'].append_empty('base_porosity')
poro_eval.set_type('independent variable', ats_input_spec.public.known_specs['independent-variable-evaluator-spec'])
poro_eval['constant in time'] = True

perm_eval = main_list['state']['field evaluators'].append_empty('permeability')
perm_eval.set_type('independent variable', ats_input_spec.public.known_specs['independent-variable-evaluator-spec'])
perm_eval['constant in time'] = True

wrm_eval = main_list['state']['field evaluators'].append_empty('saturation_liquid')
wrm_eval.set_type('WRM rel perm', ats_input_spec.public.known_specs['rel-perm-evaluator-spec'])
wrm_eval['boundary rel perm strategy'] = 'surface rel perm'
wrm_eval['permeability rescaling'] = 1e7


print(main_list['state']['field evaluators'])
# Out:
# base_porosity [TypedCollection] : [incomplete]
#   field evaluator type [string] : independent variable
#   constant in time [bool] : true
#   function [composite-vector-function-spec-list] : [incomplete]
#
# permeability [TypedCollection] : [incomplete]
#   field evaluator type [string] : independent variable
#   constant in time [bool] : true
#   function [composite-vector-function-spec-list] : [incomplete]
#
# saturation_liquid [TypedCollection] : [incomplete]
#   field evaluator type [string] : WRM rel perm
#   use density on viscosity in rel perm [bool] : true
#   boundary rel perm strategy [string] : surface rel perm
#   minimum rel perm cutoff [double] : 0.00000000
#   permeability rescaling [double] : 10000000.00000000
#   WRM parameters [wrm-typedinline-spec-list] : [incomplete]

# %%
def add_region_set_value(evaluator, ats_id, val):
    region = soil_set_name(ats_id)
    my_func = evaluator['function'].append_empty(region)
    my_func['region'] = region
    my_func['component'] = 'cell'
    my_func_const = my_func['function'].set_type('constant', 
                                                 ats_input_spec.public.known_specs['function-constant-spec'])
    my_func_const['value'] = float(val)

def add_wrm(evaluator, ats_id, props):
    region = soil_set_name(ats_id)
    wrm = wrm_eval['WRM parameters'].append_empty(region)
    wrm.set_type('van Genuchten', ats_input_spec.public.known_specs['WRM-van-Genuchten-spec'])

    wrm['region'] = region
    wrm['van Genuchten alpha [Pa^-1]'] = float(props['van Genuchten alpha [Pa^-1]'])
    wrm['van Genuchten n [-]'] = float(props['van Genuchten n [-]'])
    wrm['residual saturation [-]'] = float(props['residual saturation [-]'])
    wrm['smoothing interval width [saturation]'] = 0.05
    
    
for ats_id in subsurface_props.index:
    add_region_set_value(poro_eval, ats_id, subsurface_props.loc[ats_id]['porosity [-]'])
    add_region_set_value(perm_eval, ats_id, subsurface_props.loc[ats_id]['permeability [m^2]'])
    add_wrm(wrm_eval, ats_id, subsurface_props.loc[ats_id])

    
print(main_list['state']['field evaluators'])
# Out:
# base_porosity [TypedCollection] : [complete]
#   field evaluator type [string] : independent variable
#   constant in time [bool] : true
#   function [composite-vector-function-spec-list] : [complete]
#     GLHYMPS-715639 [TypedCollection] : [complete]
#       region [string] : GLHYMPS-715639
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.19000000
#     GLHYMPS-715779 [TypedCollection] : [complete]
#       region [string] : GLHYMPS-715779
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.09000000
#     GLHYMPS-715766 [TypedCollection] : [complete]
#       region [string] : GLHYMPS-715766
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.22000000
#     GLHYMPS-730801 [TypedCollection] : [complete]
#       region [string] : GLHYMPS-730801
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.01000000
#     NRCS-498185 [TypedCollection] : [complete]
#       region [string] : NRCS-498185
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.26556338
#     NRCS-498205 [TypedCollection] : [complete]
#       region [string] : NRCS-498205
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.15973684
#     NRCS-498206 [TypedCollection] : [complete]
#       region [string] : NRCS-498206
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.15973684
#     NRCS-498208 [TypedCollection] : [complete]
#       region [string] : NRCS-498208
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.18598639
#     NRCS-498231 [TypedCollection] : [complete]
#       region [string] : NRCS-498231
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.40321839
#     NRCS-509477 [TypedCollection] : [complete]
#       region [string] : NRCS-509477
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.42877868
#     NRCS-509479 [TypedCollection] : [complete]
#       region [string] : NRCS-509479
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.37836463
#     NRCS-509481 [TypedCollection] : [complete]
#       region [string] : NRCS-509481
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.37836463
#     NRCS-509482 [TypedCollection] : [complete]
#       region [string] : NRCS-509482
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.36988572
#     NRCS-509513 [TypedCollection] : [complete]
#       region [string] : NRCS-509513
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.23742260
#     NRCS-509514 [TypedCollection] : [complete]
#       region [string] : NRCS-509514
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.27163012
#     NRCS-509529 [TypedCollection] : [complete]
#       region [string] : NRCS-509529
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.35616318
#     NRCS-509532 [TypedCollection] : [complete]
#       region [string] : NRCS-509532
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.18223781
#     NRCS-509548 [TypedCollection] : [complete]
#       region [string] : NRCS-509548
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.19334978
#     NRCS-509559 [TypedCollection] : [complete]
#       region [string] : NRCS-509559
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.15125000
#     NRCS-509561 [TypedCollection] : [complete]
#       region [string] : NRCS-509561
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.21862464
#     NRCS-509733 [TypedCollection] : [complete]
#       region [string] : NRCS-509733
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.44975238
#     NRCS-509794 [TypedCollection] : [complete]
#       region [string] : NRCS-509794
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.41524481
#     bedrock [TypedCollection] : [complete]
#       region [string] : bedrock
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.15000000
# permeability [TypedCollection] : [complete]
#   field evaluator type [string] : independent variable
#   constant in time [bool] : true
#   function [composite-vector-function-spec-list] : [complete]
#     GLHYMPS-715639 [TypedCollection] : [complete]
#       region [string] : GLHYMPS-715639
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     GLHYMPS-715779 [TypedCollection] : [complete]
#       region [string] : GLHYMPS-715779
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     GLHYMPS-715766 [TypedCollection] : [complete]
#       region [string] : GLHYMPS-715766
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     GLHYMPS-730801 [TypedCollection] : [complete]
#       region [string] : GLHYMPS-730801
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-498185 [TypedCollection] : [complete]
#       region [string] : NRCS-498185
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-498205 [TypedCollection] : [complete]
#       region [string] : NRCS-498205
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-498206 [TypedCollection] : [complete]
#       region [string] : NRCS-498206
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-498208 [TypedCollection] : [complete]
#       region [string] : NRCS-498208
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-498231 [TypedCollection] : [complete]
#       region [string] : NRCS-498231
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509477 [TypedCollection] : [complete]
#       region [string] : NRCS-509477
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509479 [TypedCollection] : [complete]
#       region [string] : NRCS-509479
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509481 [TypedCollection] : [complete]
#       region [string] : NRCS-509481
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509482 [TypedCollection] : [complete]
#       region [string] : NRCS-509482
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509513 [TypedCollection] : [complete]
#       region [string] : NRCS-509513
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509514 [TypedCollection] : [complete]
#       region [string] : NRCS-509514
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509529 [TypedCollection] : [complete]
#       region [string] : NRCS-509529
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509532 [TypedCollection] : [complete]
#       region [string] : NRCS-509532
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509548 [TypedCollection] : [complete]
#       region [string] : NRCS-509548
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509559 [TypedCollection] : [complete]
#       region [string] : NRCS-509559
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509561 [TypedCollection] : [complete]
#       region [string] : NRCS-509561
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509733 [TypedCollection] : [complete]
#       region [string] : NRCS-509733
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     NRCS-509794 [TypedCollection] : [complete]
#       region [string] : NRCS-509794
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
#     bedrock [TypedCollection] : [complete]
#       region [string] : bedrock
#       component [string] : cell
#       function [function-typedsublistdash-spec] : [complete]
#         function-constant [False] : [complete]
#           value [double] : 0.00000000
# saturation_liquid [TypedCollection] : [incomplete]
#   field evaluator type [string] : WRM rel perm
#   use density on viscosity in rel perm [bool] : true
#   boundary rel perm strategy [string] : surface rel perm
#   minimum rel perm cutoff [double] : 0.00000000
#   permeability rescaling [double] : 10000000.00000000
#   WRM parameters [wrm-typedinline-spec-list] : [incomplete]
#     GLHYMPS-715639 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : GLHYMPS-715639
#       van Genuchten n [-] [double] : 2.00000000
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00002512
#       residual saturation [-] [double] : 0.01000000
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     GLHYMPS-715779 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : GLHYMPS-715779
#       van Genuchten n [-] [double] : 2.00000000
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00077509
#       residual saturation [-] [double] : 0.01000000
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     GLHYMPS-715766 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : GLHYMPS-715766
#       van Genuchten n [-] [double] : 2.00000000
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00029386
#       residual saturation [-] [double] : 0.01000000
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     GLHYMPS-730801 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : GLHYMPS-730801
#       van Genuchten n [-] [double] : 2.00000000
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00757447
#       residual saturation [-] [double] : 0.01000000
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-498185 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-498185
#       van Genuchten n [-] [double] : 1.31991630
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00009209
#       residual saturation [-] [double] : 0.24026950
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-498205 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-498205
#       van Genuchten n [-] [double] : 1.45755862
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00013924
#       residual saturation [-] [double] : 0.18159778
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-498206 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-498206
#       van Genuchten n [-] [double] : 1.45755862
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00013924
#       residual saturation [-] [double] : 0.18159778
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-498208 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-498208
#       van Genuchten n [-] [double] : 1.42093806
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00007058
#       residual saturation [-] [double] : 0.20831551
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-498231 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-498231
#       van Genuchten n [-] [double] : 1.41678362
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00005904
#       residual saturation [-] [double] : 0.21328539
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509477 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509477
#       van Genuchten n [-] [double] : 1.38317996
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00010265
#       residual saturation [-] [double] : 0.17513328
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509479 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509479
#       van Genuchten n [-] [double] : 1.37454007
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00007945
#       residual saturation [-] [double] : 0.23088513
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509481 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509481
#       van Genuchten n [-] [double] : 1.37454007
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00007945
#       residual saturation [-] [double] : 0.23088513
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509482 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509482
#       van Genuchten n [-] [double] : 1.39775999
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00009204
#       residual saturation [-] [double] : 0.20787742
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509513 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509513
#       van Genuchten n [-] [double] : 1.39574622
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00007174
#       residual saturation [-] [double] : 0.21959739
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509514 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509514
#       van Genuchten n [-] [double] : 1.34042910
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00007900
#       residual saturation [-] [double] : 0.24180143
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509529 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509529
#       van Genuchten n [-] [double] : 1.40609070
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00015698
#       residual saturation [-] [double] : 0.19681129
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509532 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509532
#       van Genuchten n [-] [double] : 1.42257809
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00008713
#       residual saturation [-] [double] : 0.19978347
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509548 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509548
#       van Genuchten n [-] [double] : 1.43368518
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00010384
#       residual saturation [-] [double] : 0.18931355
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509559 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509559
#       van Genuchten n [-] [double] : 1.41000990
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00007803
#       residual saturation [-] [double] : 0.21087045
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509561 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509561
#       van Genuchten n [-] [double] : 1.33281735
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00008072
#       residual saturation [-] [double] : 0.24666480
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509733 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509733
#       van Genuchten n [-] [double] : 1.76207202
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00022053
#       residual saturation [-] [double] : 0.15736573
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     NRCS-509794 [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : NRCS-509794
#       van Genuchten n [-] [double] : 1.36740826
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00014037
#       residual saturation [-] [double] : 0.22096220
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem
#     bedrock [TypedCollection] : [incomplete]
#       wrm type [string] : van Genuchten
#       region [string] : bedrock
#       van Genuchten n [-] [double] : 3.00000000
#       region [string] : None
#       van Genuchten alpha [Pa^-1] [double] : 0.00001125
#       residual saturation [-] [double] : 0.01000000
#       smoothing interval width [saturation] [double] : 0.05000000
#       Mualem exponent l [-] [double] : 0.50000000
#       Krel function name [string] : Mualem

# %%
outputs['generated_ats'] = f'../data-processed/{name}_generated_ats.xml'
ats_input_spec.io.write(main_list, outputs['generated_ats'])
main_xml = ats_input_spec.io.to_xml(main_list)
# Out:
# /Users/uec/code/ats/ats_python/rethink/ats_input_spec/io.py:43: UserWarning: Creating an incomplete XML object, missing entries!
#   warnings.warn('Creating an incomplete XML object, missing entries!')

# %%
def populate_basic_properties(xml):
    """This function updates an xml object with the above properties for mesh, regions, soil props, and lc props"""
    # find and replace the mesh list
    mesh_i = next(i for (i,el) in enumerate(xml) if el.get('name') == 'mesh')
    xml[mesh_i] = asearch.child_by_name(main_xml, 'mesh')

    # find and replace the regions list
    region_i = next(i for (i,el) in enumerate(xml) if el.get('name') == 'regions')
    xml[region_i] = asearch.child_by_name(main_xml, 'regions')

    # find and replace the WRMs list -- note here we only replace the inner "WRM parameters" because the
    # demo has this in the PK, not in the field evaluators list
    wrm_list = asearch.find_path(xml, ['PKs', 'water retention evaluator'])
    wrm_i = next(i for (i,el) in enumerate(wrm_list) if el.get('name') == 'WRM parameters')
    wrm_list[wrm_i] = asearch.find_path(main_xml, ['state','field evaluators','WRM parameters'])

    # find and replace porosity, permeability
    fe_list = asearch.find_path(xml, ['state', 'field evaluators'])
    poro_i = next(i for (i,el) in enumerate(fe_list) if el.get('name') == 'base_porosity')
    fe_list[poro_i] = asearch.find_path(main_xml, ['state', 'field evaluators', 'base_porosity'])

    perm_i = next(i for (i,el) in enumerate(fe_list) if el.get('name') == 'permeability')
    fe_list[perm_i] = asearch.find_path(main_xml, ['state', 'field evaluators', 'permeability'])

    # find and replace land cover
    consts_list = asearch.find_path(xml, ['state', 'initial conditions'])
    try:
        lc_i = next(i for (i,el) in enumerate(consts_list) if el.get('name') == 'land cover types')
    except StopIteration:
        pass
    else:
        consts_list[lc_i] = asearch.find_path(main_xml, ['state', 'initial conditions', 'land cover types'])

# %% [markdown]
# For the first file, we load a spinup template and write the needed quantities into that file, saving it to the appropriate run directory.  Note there is no DayMet or land cover or LAI properties needed for this run.  The only property that is needed is the domain-averaged, mean annual rainfall rate.  We then take off some for ET (note too wet spins up faster than too dry, so don't take off too much...).

# %%
# calculate the basin-averaged, annual-averaged precip rate
precip_total = ats_typ['precipitation rain [m s^-1]'] + ats_typ['precipitation snow [m SWE s^-1]']
mean_precip = precip_total.mean()
logging.info(f'Mean annual precip rate [m s^-1] = {mean_precip}')
# Out:
# 2021-07-23 10:15:36,501 - root - INFO: Mean annual precip rate [m s^-1] = 2.628440710810727e-08

# %%
# write the spinup xml file
# load the template file
xml = aio.fromFile('spinup_steadystate-template.xml')

# populate basic properties for mesh, regions, and soil properties
populate_basic_properties(xml)

# set the mean avg source as 60% of mean precip
precip_el = asearch.find_path(xml, ['state', 'field evaluators', 'surface-precipitation', 
                                    'function-constant', 'value'])
precip_el.setValue(mean_precip * .6)

# write to disk
outputs['spinup_filename'] = f'../run0-spinup_steadystate/spinup-{name}.xml'
aio.toFile(xml, outputs['spinup_filename'])

# make a run directory
outputs['spinup_rundir'] = f'../run0-spinup_steadystate/{name}-0'
try:
    os.mkdir(outputs['spinup_rundir'])
except FileExistsError:
    pass

# %% [markdown]
# For the second file, we load a transient run template.  This file needs the basics, plus DayMet and LAI as the "typical year data".  Also we set the run directory that will be used for the steadystate run.

# %% [markdown]
# For the third file, we load a transient run template as well.  This file needs the basics, DayMet with the actual data, and we choose for this run to use the MODIS typical year.  MODIS is only available for 2002 on, so if we didn't need 1980-2002 we could use the real data, but for this run we want a longer record.

# %%
# write the cyclic spinup xml file
# load the template file
xml = aio.fromFile('spinup_cyclic-template.xml')

# populate basic properties for mesh, regions, and soil properties
populate_basic_properties(xml)

# update the DayMet filenames
for var in ['surface-incoming_shortwave_radiation',
            'surface-precipitation_rain',
            'snow-precipitation',
            'surface-air_temperature',
            'surface-relative_humidity',
            'surface-temperature',
            'canopy-temperature']:
    try:
        par = asearch.find_path(xml, ['state', 'field evaluators', var, 'file'])
    except aerrors.MissingXMLError:
        pass
    else:
        par.setValue(os.path.join('..', outputs['daymet_spinup_filename']))

# update the LAI filenames
for par in asearch.findall_path(xml, ['canopy-leaf_area_index', 'file']):
    par.setValue(os.path.join('..', outputs['modis_typical_filename']))
    
# update the start and end time -- start at Oct 1 of year 0, end 10 years later
start_day = 274
par = asearch.find_path(xml, ['cycle driver', 'start time'])
par.setValue(start_day)

end_day = 274 + 365 * 10
par = asearch.find_path(xml, ['cycle driver', 'end time'])
par.setValue(end_day)
    
# update the restart filenames
for var in asearch.findall_path(xml, ['initial conditions', 'restart file']):
    var.setValue(os.path.join('..', outputs['spinup_rundir'], 'checkpoint_final.h5'))

# write to disk
outputs['spinup_cyclic_filename'] = f'../run1-spinup_cyclic_steadystate/spinup_cyclic-{name}.xml'
aio.toFile(xml, outputs['spinup_cyclic_filename'])

# make a run directory
outputs['spinup_cyclic_rundir'] = f'../run1-spinup_cyclic_steadystate/{name}-0'
try:
    os.mkdir(outputs['spinup_cyclic_rundir'])
except FileExistsError:
    pass

# %%
# write the transient xml file
# load the template file
xml = aio.fromFile('transient-template.xml')

# populate basic properties for mesh, regions, and soil properties
populate_basic_properties(xml)

# update the DayMet filenames
for var in ['surface-incoming_shortwave_radiation',
            'surface-precipitation_rain',
            'snow-precipitation',
            'surface-air_temperature',
            'surface-relative_humidity',
            'surface-temperature',
            'canopy-temperature']:
    try:
        par = asearch.find_path(xml, ['state', 'field evaluators', var, 'file'])
    except aerrors.MissingXMLError:
        pass
    else:
        par.setValue(os.path.join('..', outputs['daymet_filename']))
 
#  update the LAI filename
for par in asearch.findall_path(xml, ['canopy-leaf_area_index', 'file']):
    par.setValue(os.path.join('..', outputs['modis_typical_filename']))

# update the start time
start_day = 274 + 365*(start_year - 1980)
par = asearch.find_path(xml, ['cycle driver', 'start time'])
par.setValue(start_day)

end_day = 274 + 365*(2020 - 1980)
par = asearch.find_path(xml, ['cycle driver', 'end time'])
par.setValue(end_day)

# update the restart filenames
for var in asearch.findall_path(xml, ['initial conditions', 'restart file']):
    var.setValue(os.path.join('..', outputs['spinup_cyclic_rundir'], 'checkpoint_final.h5'))

# write to disk
outputs['transient_filename'] = f'../run2-transient/transient-{name}_{start_year}_2020.xml'
aio.toFile(xml, outputs['transient_filename'])

# make a run directory
outputs['transient_rundir'] = f'../run2-transient/{name}_{start_year}_2020-0'
try:
    os.mkdir(outputs['transient_rundir'])
except FileExistsError:
    pass

# %%
logging.info('this workflow is a total success')
# Out:
# 2021-07-23 10:15:36,592 - root - INFO: this workflow is a total success
